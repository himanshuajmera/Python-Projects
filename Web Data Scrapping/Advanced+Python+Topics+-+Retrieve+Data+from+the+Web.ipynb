# %% [markdown]
# # Advanced Python Topics - Retrieve Data from the Web
#
# In this notebook, we will learn some advanced topics in Python language. When programs get big, we probably want to divide the code into multiple blocks and smaller files for better management. So, the functions of each block can be reused. It sounds more like the functions we learned before. Actually, each module of python code is a collection of functions. A module usually contains Python files ending with ".py". Python modules are commonly regarded as libraries, called in other high level programming languages. Multiple modules can be bundled together to create packages. This modular approach improves program's readability and creates building blocks for large projects considering that modules can be built by different people at different time. We now can quickly create a program using these prebuilt or user-defined modules or libraries. When we need the functions inside these libraries, we just need to "import" them into our code. We don't have to read or fully understand the source code of the libraries we are importing. But we do have to know how to interface with the functions. Libraries usually come with documentations describe how to use the functions.

# %%
#When python is installed, a set of standard libries are installed with it. These libraries are called standard because
#users don't have to installed manually. But if you do see error messages saying the module's not found, you have to install
#that particular module using "pip install" or "conda install". 

#import the math library into our program. 
import math

# %%
#All the functions defined in math library can be called under math.
#Use Tab key to see all the available functions
math.factorial(5)
# Out:
# 120

# %%
print(1*2*3*4*5)
# Out:
# 120

# %%
#We can also use from 'lib' import 'functions' to only import specific functions 
#or all functions using *
#But the functions imported are regarded global functions that are no longer 
#managed by math. package name
from math import factorial

# %%
print(m.factorial(5))
# Out:
# 120

# %%
print(fac(5))
# Out:
# 120

# %%
#we can use "as" to create shorter aliases for libraries
#we will call math m in our program
import math as m
#we will call factorial as fac
from math import factorial as fac
#we can import all the functions as global functions using *
#this may be dangerous if you created your own function with the same names of the imported functions
from math import *

# %%
from math import log2

# %%
from math import *

# %%
#log2() is available because we imported *
print(log2(1024))

#math is called m now
print(m.factorial(5))

#and factorial is called fac now
print(fac(5))

#why m.fac() doesn't exist? 
print(m.fac(5))
# Out:
# 10.0
# 120
# 120
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-117-d3e2a6123839> in <module>()
#       9
#      10 #why m.fac() doesn't exist?
# ---> 11 print(m.fac(5))
#
# AttributeError: module 'math' has no attribute 'fac'

# %%
#Now, let's define our own factorial function

def factorial(n):
    fac=1
    for i in range(n):
        fac *= i+1
    #to make the function different from the factorial function defined in math library
    #we meke the return value a string
    return str(fac)

factorial(5)  
#we can see that the function that is called is the function we defined in our code
#this means that if there is a name conflict between our defined function and the imported function
#the user defined function will take priority.
# Out:
# '120'

# %%
#It's not just functions that can be imported, global variables can be imported as well
print(m.pi) #import math as m
print(pi)  #from math import *
print('{0:.6}'.format(pi))
# Out:
# 3.141592653589793
# 3.141592653589793
# 3.14159

# %% [markdown]
# # Use Standard and External Python Modules
# After we learned how to import python modules/libraries, let's learn how to use them to quickly solve data retrieval challenges.
# We will first look at how to retrieve texts from web pages. <br>
# [urllib library](https://docs.python.org/3/library/urllib.html) <br>
# [regular expression - re library](https://docs.python.org/3/library/re.html) <br>
# [beautifulsoup library](https://www.crummy.com/software/BeautifulSoup/) <br>
# [beautifulsoup documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)

# %%
#use urllib library to open a URL and import the webpage contents as a string
import urllib.request

#use urlopen function in the request sub-library
#the page contains the popular names used in world catagorized by countries 
html = urllib.request.urlopen("https://en.wikipedia.org/wiki/List_of_most_popular_given_names")

#read in the htmltext as reading from an open file
htmltext=html.read()

#htmltext was read in as bytes
print(type(htmltext))

#convert bytes to string so the string can be written to a text file
htmltext = str(htmltext)

#write what we retrieved from the url to an html file and see if we get the right content
f=open('test.html','w')
f.write(htmltext)
f.close

print(htmltext)
# Out:
# <class 'bytes'>
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of most popular given names - Wikipedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_most_popular_given_names","wgTitle":"List of most popular given names","wgCurRevisionId":760958348,"wgRevisionId":760958348,"wgArticleId":375845,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 errors: external links","All articles with dead external links","Articles with dead external links from June 2016","CS1 errors: invisible characters","Dynamic lists","All articles with unsourced statements","Articles with unsourced statements from December 2008","Articles with unsourced statements from September 2008","Lists of popular names","Names by culture","Given names","Infancy"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"List_of_most_popular_given_names","wgRelevantArticleId":375845,"wgRequestId":"WIK5XgpAMFwAAA3hHyQAAADA","wgIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgWikiEditorEnabledModules":{"toolbar":true,"dialogs":true,"preview":false,"publish":false},"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgRelatedArticles":null,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCategoryTreePageCategoryOptions":"{\\"mode\\":0,\\"hideprefix\\":20,\\"showcount\\":true,\\"namespaces\\":false}","wgWikibaseItemId":"Q6629080","wgCentralAuthMobileDomain":false,"wgVisualEditorToolbarScrollOffset":0,"wgEditSubmitButtonLabelPublish":false});mw.loader.state({"ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"loading","user.tokens":"loading","ext.cite.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready"});mw.loader.implement("user.options@0j3lz3q",function($,jQuery,require,module){mw.user.options.set({"variant":"en"});});mw.loader.implement("user.tokens@1dqfd7l",function ( $, jQuery, require, module ) {\nmw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});/*@nomin*/;\n\n});mw.loader.load(["ext.cite.a11y","mediawiki.toc","mediawiki.action.view.postEdit","site","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.legacy.wikibits","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","e ...

# %%
#Collect all the words into a list using split()
#by default split() uses whitespaces as separaters including spaces, tabs, new lines ...
words = htmltext.split()
words
# Out:
# ["b'<!DOCTYPE",
#  'html>\\n<html',
#  'class="client-nojs"',
#  'lang="en"',
#  'dir="ltr">\\n<head>\\n<meta',
#  'charset="UTF-8"/>\\n<title>List',
#  'of',
#  'most',
#  'popular',
#  'given',
#  'names',
#  '-',
#  'Wikipedia</title>\\n<script>document.documentElement.className',
#  '=',
#  'document.documentElement.className.replace(',
#  '/(^|\\\\s)client-nojs(\\\\s|$)/,',
#  '"$1client-js$2"',
#  ');</script>\\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_most_popular_given_names","wgTitle":"List',
#  'of',
#  'most',
#  'popular',
#  'given',
#  'names","wgCurRevisionId":760958348,"wgRevisionId":760958348,"wgArticleId":375845,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1',
#  'errors:',
#  'external',
#  'links","All',
#  'articles',
#  'with',
#  'dead',
#  'external',
#  'links","Articles',
#  'with',
#  'dead',
#  'external',
#  'links',
#  'from',
#  'June',
#  '2016","CS1',
#  'errors:',
#  'invisible',
#  'characters","Dynamic',
#  'lists","All',
#  'articles',
#  'with',
#  'unsourced',
#  'statements","Articles',
#  'with',
#  'unsourced',
#  'statements',
#  'from',
#  'December',
#  '2008","Articles',
#  'with',
#  'unsourced',
#  'statements',
#  'from',
#  'September',
#  '2008","Lists',
#  'of',
#  'popular',
#  'names","Names',
#  'by',
#  'culture","Given',
#  'names","Infancy"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"List_of_most_popular_given_names","wgRelevantArticleId":375845,"wgRequestId":"WIK5XgpAMFwAAA3hHyQAAADA","wgIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgWikiEditorEnabledModules":{"toolbar":true,"dialogs":true,"preview":false,"publish":false},"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgRelatedArticles":null,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCategoryTreePageCategoryOptions":"{\\\\"mode\\\\":0,\\\\"hideprefix\\\\":20,\\\\"showcount\\\\":true,\\\\"namespaces\\\\":false}","wgWikibaseItemId":"Q6629080","wgCentralAuthMobileDomain":false,"wgVisualEditorToolbarScrollOffset":0,"wgEditSubmitButtonLabelPublish":false});mw.loader.state({"ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"loading","user.tokens":"loading","ext.cite.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready"});mw.loader.implement("user.options@0j3lz3q",function($,jQuery,require,module){mw.user.options.set({"variant":"en"});});mw.loader.implement("user.tokens@1dqfd7l",function',
#  '(',
#  '$,',
#  'jQuery,',
#  'require,',
#  'module',
#  ')',
#  '{\\nmw.user.tokens.set({"editToken":"+\\\\\\\\","patrolToken":"+\\\\\\\\","watchToken":"+\\\\\\\\","csrfToken":"+\\\\\\\\"});/*@nomin*/;\\n\\n});mw.loader.load(["ext.cite.a11y","mediawiki.toc","mediawiki.action.view.postEdit","site","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.legacy.wikibits","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.gadget.featured-articles-links","ext.centralauth.centralautologin","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.interface","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"]);});</script>\\n<link',
#  'rel="stylesheet"',
#  'href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>\\n<script',
#  'async=""',
#  'src="/w/load.php?debug=false&amp;lang=en&amp;modules=startup&amp;only=scripts&amp;skin=vector"></script>\\n<meta',
#  'name="ResourceLoaderDynamicStyles"',
#  'content=""/>\\n<link',
#  'rel="stylesheet"',
#  'href="/w/load.php?debug=false&amp;lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>\\n<meta',
#  'name="generator"',
#  'content="MediaWiki',
#  '1.29.0-wmf.8"/>\\n<meta',
#  'name="referrer"',
#  'content="origin-when-cross-origin"/>\\n<link',
#  'rel="alternate"',
#  'href="android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/List_of_most_popular_given_names"/>\\n<link',
#  'rel="alternate"',
#  'type="application/x-wiki"',
#  'title="Edit',
#  'this',
#  'page"',
#  'href="/w/index.php?title=List_of_most_popular_given_names&amp;action=edit"/>\\n<link',
#  'rel="edit"',
#  'title="Edit',
#  'this',
#  'page"',
#  'href="/w/index.php?title=List_of_most_popular_given_names&amp;action=edit"/>\\n<link',
#  'rel="apple-touch-icon"',
#  'href="/static/apple-touch/wikipedia.png"/>\\n<link',
#  'rel="shortcut',
#  'icon"',
#  'href="/static/favicon/wikipedia.ico"/>\\n<link',
#  'rel="search"',
#  'type="application/opensearchdescription+xml"',
#  'href="/w/opensearch_desc.php"',
#  'title="Wikipedia',
#  '(en)"/>\\n<link',
#  'rel="EditURI"',
#  'type="application/rsd+xml"',
#  'href="//en.wikipedia.org/w/api.php?action=rsd"/>\\n<link',
#  'rel="copyright"',
#  'href="//creativecommons.org/licenses/by-sa/3.0/"/>\\n<link',
#  'rel="canonical"',
#  'href="https://en.wikipedia.org/wiki/List_of_most_popular_given_names"/>\\n<link',
#  'rel="dns-prefetch"',
#  'href="//login.wikimedia.org"/>\\n<link',
#  'rel="dns-prefetch"',
#  'href="//meta.wikimedia.org"',
#  '/>\\n</head>\\n<body',
#  'class="mediawiki',
#  'ltr',
#  'sitedir-ltr',
#  'mw-hide-empty-elt',
#  'ns-0',
#  'ns-subject',
#  'page-List_of_most_popular_given_names',
#  'rootpage-List_of_most_popular_given_names',
#  'skin-vector',
#  'action-view">\\t\\t<div',
#  'id="mw-page-base"',
#  'class="noprint"></div>\\n\\t\\t<div',
#  'id="mw-head-base"',
#  'class="noprint"></div>\\n\\t\\t<div',
#  'id="content"',
#  'class="mw-body"',
#  'role="main">\\n\\t\\t\\t<a',
#  'id="top"></a>\\n\\n\\t\\t\\t\\t\\t\\t\\t<div',
#  'id="siteNotice"><!--',
#  'CentralNotice',
#  '--></div>\\n\\t\\t\\t\\t\\t\\t<div',
#  'class="mw-indicators">\\n</div>\\n\\t\\t\\t<h1',
#  'id="firstHeading"',
#  'class="firstHeading"',
#  'lang="en">List',
#  'of',
#  'most',
#  'popular',
#  'given',
#  'names</h1>\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t<div',
#  'id="bodyContent"',
#  'class="mw-body-content">\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t<div',
#  'id="siteSub">From',
#  'Wikipedia,',
#  'the',
#  'free',
#  'encyclopedia</div>\\n\\t\\t\\t\\t\\t\\t\\t\\t<div',
#  'id="contentSub"></div>\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t<div',
#  'id="jump-to-nav"',
#  'class="mw-jump">\\n\\t\\t\\t\\t\\tJump',
#  'to:\\t\\t\\t\\t\\t<a',
#  'href="#mw-head">navigation</a>,',
#  '\\t\\t\\t\\t\\t<a',
#  'href="#p-search">search</a>\\n\\t\\t\\t\\t</div>\\n\\t\\t\\t\\t<div',
#  'id="mw-content-text"',
#  'lang="en"',
#  'dir="ltr"',
#  'class="mw-content-ltr"><script>function',
#  'mfTempOpenSection(id){var',
#  'block=document.getElementById("mf-section-"+id);block.className+="',
#  'open-block";block.previousSibling.className+="',
#  'open-block";}</script><div',
#  'role="note"',
#  'class="hatnote">This',
#  'page',
#  'is',
#  'about',
#  '<a',
#  'href="/wiki/Given_name"',
#  'title="Given',
#  'name">forenames</a>.',
#  'Not',
#  'to',
#  'be',
#  'confused',
#  'with',
#  '<a',
#  'href="/wiki/Lists_of_most_common_surnames"',
#  'title="Lists',
#  'of',
#  'most',
#  'common',
#  'surnames">Lists',
#  'of',
#  'most',
#  'common',
#  'surnames</a>.</div>\\n<p>The',
#  '<b>most',
#  'popular',
#  'given',
#  'names</b>',
#  'vary',
#  '<a',
#  'href="/wiki/Country"',
#  'title="Country">nationally</a>,',
#  '<a',
#  'href="/wiki/Region"',
#  'title="Region">regionally</a>,',
#  'and',
#  '<a',
#  'href="/wiki/Culture"',
#  'title="Culture">culturally</a>.',
#  'Lists',
#  'of',
#  'widely',
#  'used',
#  '<a',
#  'href="/wiki/Given_name"',
#  'title="Given',
#  'name">given',
#  'names</a>',
#  'can',
#  'consist',
#  'of',
#  'those',
#  'most',
#  'often',
#  'bestowed',
#  'upon',
#  '<a',
#  'href="/wiki/Infant"',
#  'title="Infant">infants</a>',
#  'born',
#  'within',
#  'the',
#  'last',
#  'year,',
#  'thus',
#  'reflecting',
#  'the',
#  'current',
#  '<a',
#  'href="/wiki/Onomastics"',
#  'title="Onomastics">naming',
#  'trends</a>,',
#  'or',
#  'else',
#  'be',
#  'composed',
#  'of',
#  'the',
#  '<a',
#  'href="/wiki/Personal_name"',
#  'title="Personal',
#  'name">personal',
#  'names</a>',
#  'occurring',
#  'most',
#  'within',
#  'the',
#  'total',
#  '<a',
#  'href="/wiki/Population"',
#  'title="Population">population</a>.</p>\\n<p></p>\\n<div',
#  'id="toc"',
#  'class="toc">\\n<div',
#  'id="toctitle">\\n<h2>Contents</h2>\\n</div>\\n<ul>\\n<li',
#  'class="toclevel-1',
#  'tocsection-1"><a',
#  'href="#Popularity_by_region"><span',
#  'class="tocnumber">1</span>',
#  '<span',
#  'class="toctext">Popularity',
#  'by',
#  'region</span></a>\\n<ul>\\n<li',
#  'class="toclevel-2',
#  'tocsection-2"><a',
#  'href="#Africa"><span',
#  'class="tocnumber">1.1</span>',
#  '<span',
#  'class="toctext">Africa</span></a>\\n<ul>\\n<li',
#  'class="toclevel-3',
#  'tocsection-3"><a',
#  'href="#Male_names"><span',
#  'class="tocnumber">1.1.1</span>',
#  '<span',
#  'class="toctext">Male',
#  'names</span></a></li>\\n<li',
#  'class="toclevel-3',
#  'tocsection-4"><a',
#  'href="#Female_names"><span',
#  'class="tocnumber">1.1.2</span>',
#  '<span',
#  'class="toctext">Female',
#  'names</span></a></li>\\n</ul>\\n</li>\\n<li',
#  'class="toclevel-2',
#  'tocsection-5"><a',
#  'href="#Americas"><span',
#  'class="tocnumber">1.2</span>',
#  '<span',
#  'class="toctext">Americas</span></a>\\n<ul>\\n<li',
#  'class="toclevel-3',
#  'tocsection-6"><a',
#  'href="#Male_names_2"><span',
#  'class="tocnumber">1.2.1</span>',
#  '<span',
#  'class="toctext">Male',
#  'names</span></a></li>\\n<li',
#  'class="toclevel-3',
#  'tocsection-7"><a',
#  'href="#Female_names_2"><span',
#  'class="tocnumber">1.2.2</span>',
#  '<span',
#  'class="toctext">Female',
#  'names</span></a></li>\\n</ul>\\n</li>\\n<li',
#  'class="toclevel-2',
#  'tocsection-8"><a',
#  'href="#Asia"><span',
#  'class="tocnumber">1.3</span>',
#  '<span',
#  'class="toctext">Asia</span></a>\\n<ul>\\n<li',
#  'class="toclevel-3',
#  'tocsection-9"><a',
#  'href="#Male_names_3"><span',
#  'class="tocnumber">1.3.1</span>',
#  '<span',
#  'class="toctext">Male',
#  'names</span></a></li>\\n<li',
#  'class="toclevel-3',
#  'tocsection-10"><a',
#  'href="#Female_names_3"><span',
#  'class="tocnumber">1.3.2</span>',
#  '<span',
#  'class="toctext">Female',
#  'names</span></a></li>\\n</ul>\\n</li>\\n<li',
#  'class="toclevel-2',
#  'tocsection-11"><a',
#  'href="#Europe"><span',
#  'class="tocnumber">1.4</span>',
#  '<span',
#  'class="toctext">Europe</span></a>\\n<ul>\\n<li',
#  'class="toclevel-3',
#  'tocsection-12"><a',
#  'href="#Male_names_4"><span',
#  'class="tocnumber">1.4.1</span>',
#  '<span',
#  'class="toctext">Male',
#  'names</span></a></li>\\n<li',
#  'class="toclevel-3',
#  'tocsection-13"><a',
#  'href="#Female_names_4"><span',
#  'class="tocnumber">1.4.2</span>',
#  '<span',
#  'class="toctext">Female',
#  'names</span></a></li>\\n</ul>\\n</li>\\n<li',
#  'class="toclevel-2',
#  'tocsection-14"><a',
#  'href="#Oceania"><span',
#  'class="tocnumber">1.5</span>',
#  '<span',
#  'class="toctext">Oceania</span></a>\\n<ul>\\n<li',
#  'class="toclevel-3',
#  'tocsection-15"><a',
#  'href="#Male_names_5"><span',
#  'class="tocnumber">1.5.1</span>',
#  '<span',
#  'class="toctext">Male',
#  'names</span></a></li>\\n<li',
#  'class="toclevel-3',
#  'tocsection-16"><a',
#  'href="#Female_names_5"><span',
#  'class="tocnumber">1.5.2</span>',
#  '<span',
#  'class="toctext">Female',
#  'names</span></a></li>\\n</ul>\\n</li>\\n</ul>\\n</li>\\n<li',
#  'class="toclevel-1',
#  'tocsection-17"><a',
#  'href="#See_also"><span',
#  'class="tocnumber">2</span>',
#  '<span',
#  'class="toctext">See',
#  'also</span></a></li>\\n<li',
#  'class="toclevel-1',
#  'tocsection-18"><a',
#  'href="#References"><span',
#  'class="tocnumber">3</span>',
#  '<span',
#  'class="toctext">References</span></a></li>\\n<li',
#  'class="toclevel-1',
#  'tocsection-19"><a',
#  'href="#External_links"><span',
#  'class="tocnumber">4</span>',
#  '<span',
#  'class="toctext">External',
#  'links</span></a>\\n<ul>\\n<li',
#  'class="toclevel-2',
#  'tocsection-20"><a',
#  'href="#Articles"><span',
#  'class="tocnumber">4.1</span>',
#  '<span',
#  'class="toctext">Articles</span></a></li>\\n<li',
#  'class="toclevel-2',
#  'tocsection-21"><a',
#  'href="#Government_statistics"><span',
#  'class="tocnumber">4.2</span>',
#  '<span',
#  'class="toctext">Government',
#  'statistics</span></a></li>\\n</ul>\\n</li>\\n</ul>\\n</div>\\n<p></p>\\n<h2><span',
#  'class="mw-headline"',
#  'id="Popularity_by_region">Popularity',
#  'by',
#  'region</span><span',
#  'class="mw-editsection"><span',
#  'class="mw-editsection-bracket">[</span><a',
#  'href="/w/index.php?title=List_of_most_popular_given_names&amp;action=edit&amp;section=1"',
#  'title="Edit',
#  'section:',
#  'Popularity',
#  'by',
#  'region">edit</a><span',
#  'class="mw-editsection-bracket">]</span></span></h2>\\n<p>The',
#  'names',
#  'listed',
#  'in',
#  'the',
#  'following',
#  'tables,',
#  'unless',
#  'otherwise',
#  'noted,',
#  'represent',
#  'the',
#  'most',
#  'current',
#  'top',
#  '10',
#  'breakdowns',
#  'of',
#  'what',
#  'newborn',
#  'children',
#  'are',
#  'commonly',
#  'being',
#  'named',
#  'in',
#  'the',
#  'various',
#  'regions',
#  'of',
#  'the',
#  'world.</p>\\n<div',
#  'role="note"',
#  'class="hatnote',
#  'plainlinks">This',
#  'is',
#  'a',
#  '<a',
#  'href="/wiki/Wikipedia:WikiProject_Lists#Incomplete_lists"',
#  'title="Wikipedia:WikiProject',
#  'Lists">dynamic',
#  'list</a>',
#  'and',
#  'may',
#  'never',
#  'be',
#  'able',
#  'to',
#  'satisfy',
#  'particular',
#  'standards',
#  'for',
#  'completeness.',
#  'You',
#  'can',
#  'help',
#  'by',
#  '<a',
#  'class="external',
#  'text"',
#  'href="//en.wikipedia.org/w/index.php?title=List_of_most_popular_given_names&amp;action=edit">expanding',
#  'it</a>',
#  'with',
#  '<a',
#  'href="/wiki/Wikipedia:Identifying_reliable_sources"',
#  'title="Wikipedia:Identifying',
#  'reliable',
#  'sources">reliably',
#  'sourced</a>',
#  'entries.</div>\\n<h3><span',
#  'class="mw-headline"',
#  'id="Africa">Africa</span><span',
#  'class="mw-editsection"><span',
#  'class="mw-editsection-bracket">[</span><a',
#  'href="/w/index.php?title=List_of_most_popular_given_names&amp;action=edit&amp;section=2"',
#  'title="Edit',
#  'section:',
#  'Africa">edit</a><span',
#  'class="mw-editsection-bracket">]</span></span></h3>\\n<h4><span',
#  'class="mw-headline"',
#  'id="Male_names">Male',
#  'names</span><span',
#  'class="mw-editsection"><span',
#  'class="mw-editsection-bracket">[</span><a',
#  'href="/w/index.php?title=List_of_most_popular_given_names&amp;action=edit&amp;section=3"',
#  'title="Edit',
#  'section:',
#  'Male',
#  'names">edit</a><span',
#  'class="mw-editsection-bracket">]</span></span></h4>\\n<table',
#  'class="wikitable">\\n<tr',
#  'style="background:#a0d0ff;">\\n<th',
#  'style="width:300px;">Region',
#  '(year)</th>\\n<th>No.',
#  '1</th>\\n<th>No.',
#  '2</th>\\n<th>No.',
#  '3</th>\\n<th>No.',
#  '4</th>\\n<th>No.',
#  '5</th>\\n<th>No.',
#  '6</th>\\n<th>No.',
#  '7</th>\\n<th>No.',
#  '8</th>\\n<th>No.',
#  '9</th>\\n<th>No.',
#  '10</th>\\n</tr>\\n<tr>\\n<td><a',
#  'href="/wiki/Algeria"',
#  'title="Algeria">Algeria</a>',
#  '(census,',
#  '2010)<sup',
#  'id="cite_ref-ine.es_1-0"',
#  'class="reference"><a',
#  'href="#cite_note-ine.es-1">[1]</a></sup></td>\\n<td><a',
#  'href="/wiki/Muhammad_(name)"',
#  'title="Muhammad',
#  '(name)">Mohamed</a></td>\\n<td>Abdelkader</td>\\n<td><a',
#  'href="/wiki/Ahmad"',
#  'title="Ahmad">Ahmed</a></td>\\n<td><a',
#  'href="/wiki/Muhammad_(name)"',
#  'title="Muhammad',
#  '(name)">Mohammed</a></td>\\n<td><a',
#  'href="/wiki/Ali_(name)"',
#  'title="Ali',
#  '(name)">Ali</a></td>\\n<td>Rachid</td>\\n<td>Said</td>\\n<td><a',
#  'href="/wiki/Ibrahim_(name)"',
#  'title="Ibrahim',
#  '(name)">Brahim</a></td>\\n<td><a',
#  'href="/wiki/Omar_(name)"',
#  'title="Omar',
#  '(name)">Omar</a></td>\\n<td>Djamel</td>\\n</tr>\\n<tr>\\n<td><a',
#  'href="/wiki/Egypt"',
#  'title="Egypt">Egypt</a>',
#  '(2004,',
#  'unofficial)<sup',
#  'id="cite_ref-ahram2004_2-0"',
#  'class="reference"><a',
#  'href="#cite_note-ahram2004-2">[2]</a></sup></td>\\n<td><a',
#  'href="/wiki/Muhammad_(name)"',
#  'title="Muhammad',
#  '(name)">Mohamed</a>,',
#  '<a',
#  'href="/wiki/Joseph_(given_name)"',
#  'class="mw-redirect"',
#  'title="Joseph',
#  '(given',
#  'name)">Youssef</a>,',
#  '<a',
#  'href="/wiki/Ahmad"',
#  'title="Ahmad">Ahmed</a>,',
#  '<a',
#  'href="/wiki/Mahmud"',
#  'title="Mahmud">Mahmoud</a>,',
#  '<a',
#  'href="/wiki/Mustafa"',
#  'title="Mustafa">Mustafa</a>,',
#  'Yassin,',
#  '<a',
#  'href="/wiki/Taha_(name)"',
#  'title="Taha',
#  '(name)">Taha</a>,',
#  'Khaled,',
#  '<a',
#  'href="/wiki/Hamza_(name)"',
#  'title="Hamza',
#  '(name)">Hamza</a>,',
#  'Bilal,',
#  '<a',
#  'href="/wiki/Ibrahim_(name)"',
#  'title="Ibrahim',
#  '(name)">Ibrahim</a>,',
#  '<a',
#  'href="/wiki/Hassan_(given_name)"',
#  'title="Hassan',
#  '(given',
#  'name)">Hassan</a>,',
#  '<a',
#  'href="/wiki/Hussein"',
#  'title="Hussein">Hussein</a>,',
#  '<a',
#  'href="/wiki/Karim"',
#  'title="Karim">Karim</a>,',
#  '<a',
#  'href="/wiki/Tariq_(given_name)"',
#  'class="mw-redirect"',
#  'title="Tariq',
#  '(given',
#  'name)">Tareq</a>,',
#  '<a',
#  'href="/wiki/Abdur_Rahman"',
#  'class="mw-redirect"',
#  'title="Abdur',
#  'Rahman">Abdel-Rahman</a>,',
#  '<a',
#  'href="/wiki/Ali_(name)"',
#  'title="Ali',
#  '(name)">Ali</a>,',
#  '<a',
#  'href="/wiki/Omar_(name)"',
#  'title="Omar',
#  '(name)">Omar</a>,',
#  '<a',
#  'href="/wiki/Halim"',
#  'title="Halim">Halim</a>,',
#  '<a',
#  'href="/wiki/Murad"',
#  'title="Murad">Murad</a>,',
#  '<a',
#  'href="/wiki/Salem_(name)"',
#  'title="Salem',
#  '(name)">Selim</a>,',
#  '<a',
#  'href="/wiki/Abdullah_(name)"',
#  'title="Abdullah',
#  '(name)">Abdallah</a></td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n</tr>\\n<tr>\\n<td><a',
#  'href="/wiki/Egypt"',
#  'title="Egypt">Egypt</a>',
#  '(2004,',
#  '<a',
#  'href="/wiki/Coptic_Christians"',
#  'class="mw-redirect"',
#  'title="Coptic',
#  'Christians">Coptic',
#  'Christians</a>,',
#  'unofficial)<sup',
#  'id="cite_ref-ahram2004_2-1"',
#  'class="reference"><a',
#  'href="#cite_note-ahram2004-2">[2]</a></sup></td>\\n<td><a',
#  'href="/wiki/Peter_(given_name)"',
#  'title="Peter',
#  '(given',
#  'name)">Peter,',
#  'Pierre</a>,',
#  '<a',
#  'href="/wiki/George_(given_name)"',
#  'title="George',
#  '(given',
#  'name)">George</a>,',
#  '<a',
#  'href="/wiki/John_(given_name)"',
#  'title="John',
#  '(given',
#  'name)">John</a>,',
#  '<a',
#  'href="/wiki/Mina_(given_name)"',
#  'title="Mina',
#  '(given',
#  'name)">Mina</a>,',
#  'Beshoi,',
#  '<a',
#  'href="/wiki/Cyril"',
#  'title="Cyril">Kirollos</a>,',
#  '<a',
#  'href="/wiki/Mark_(given_name)"',
#  'class="mw-redirect"',
#  'title="Mark',
#  '(given',
#  'name)">Mark</a>,',
#  'Fadi,',
#  '<a',
#  'href="/wiki/Habib"',
#  'title="Habib">Habib</a></td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n</tr>\\n<tr>\\n<td><a',
#  'href="/wiki/Equatorial_Guinea"',
#  'title="Equatorial',
#  'Guinea">Equatorial',
#  'Guinea</a>',
#  '(2011)<sup',
#  'id="cite_ref-elconfidencial.com_3-0"',
#  'class="reference"><a',
#  'href="#cite_note-elconfidencial.com-3">[3]</a></sup></td>\\n<td><a',
#  'href="/wiki/Manuel_(name)"',
#  'title="Manuel',
#  '(name)">Manuel</a></td>\\n<td><a',
#  'href="/wiki/Juan"',
#  'title="Juan">Juan</a></td>\\n<td><a',
#  'href="/wiki/Antonio"',
#  'title="Antonio">Antonio</a></td>\\n<td><a',
#  'href="/wiki/Joseph_(name)"',
#  'class="mw-redirect"',
#  'title="Joseph',
#  '(name)">Jos\\xc3\\xa9</a></td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n</tr>\\n<tr>\\n<td><a',
#  'href="/wiki/Libya"',
#  'title="Libya">Libya</a><sup',
#  'class="noprint',
#  'Inline-Template',
#  'Template-Fact"',
#  'style="white-space:nowrap;">[<i><a',
#  'href="/wiki/Wikipedia:Citation_needed"',
#  'title="Wikipedia:Citation',
#  'needed"><span',
#  'title="This',
#  'claim',
#  'needs',
#  'references',
#  'to',
#  'reliable',
#  'sources.',
#  '(December',
#  '2008)">citation',
#  'needed</span></a></i>]</sup></td>\\n<td><a',
#  'href="/wiki/Muhammad_(name)"',
#  'title="Muhammad',
#  '(name)">Mohammed</a></td>\\n<td><a',
#  'href="/wiki/Ahmad"',
#  'title="Ahmad">Ahmed</a></td>\\n<td><a',
#  'href="/wiki/Ali_(name)"',
#  'title="Ali',
#  '(name)">Ali</a></td>\\n<td><a',
#  'href="/wiki/Hamza_(name)"',
#  'title="Hamza',
#  '(name)">Hamza</a></td>\\n<td><a',
#  'href="/wiki/Ibrahim_(name)"',
#  'title="Ibrahim',
#  '(name)">Ibrahim</a></td>\\n<td><a',
#  'href="/wiki/Mahmud"',
#  'title="Mahmud">Mahmoud</a></td>\\n<td><a',
#  'href="/wiki/Abdullah_(name)"',
#  'title="Abdullah',
#  '(name)">Abdallah</a></td>\\n<td><a',
#  'href="/wiki/Tariq_(given_name)"',
#  'class="mw-redirect"',
#  'title="Tariq',
#  '(given',
#  'name)">Tareq</a></td>\\n<td><a',
#  'href="/wiki/Hassan_(given_name)"',
#  'title="Hassan',
#  '(given',
#  'name)">Hassan</a></td>\\n<td>Khaled</td>\\n</tr>\\n<tr>\\n<td><a',
#  'href="/wiki/Mali"',
#  'title="Mali">Mali</a>',
#  '(census,',
#  '2010)<sup',
#  'id="cite_ref-ine.es_1-1"',
#  'class="reference"><a',
#  'href="#cite_note-ine.es-1">[1]</a></sup></td>\\n<td><a',
#  'href="/wiki/Mamadou"',
#  'title="Mamadou">Mamadou</a></td>\\n<td><a',
#  'href="/wiki/Moussa"',
#  'title="Moussa">Moussa</a></td>\\n<td>Mahamadou</td>\\n<td>Adama</td>\\n<td>Bakary</td>\\n<td><a',
#  'href="/wiki/Abdoulaye"',
#  'title="Abdoulaye">Abdoulaye</a></td>\\n<td>Modibo</td>\\n<td>Oumar</td>\\n<td><a',
#  'href="/wiki/Sekou"',
#  'title="Sekou">Sekou</a></td>\\n<td>Souleymane</td>\\n</tr>\\n<tr>\\n<td><a',
#  'href="/wiki/Morocco"',
#  'title="Morocco">Morocco</a><sup',
#  'id="cite_ref-4"',
#  'class="reference"><a',
#  'href="#cite_note-4">[4]</a></sup></td>\\n<td><a',
#  'href="/wiki/Muhammad_(name)"',
#  'title="Muhammad',
#  '(name)">Mohamed</a></td>\\n<td><a',
#  'href="/wiki/Ahmad"',
#  'title="Ahmad">Ahmed</a></td>\\n<td><a',
#  'href="/wiki/Muhammad_(name)"',
#  'title="Muhammad',
#  '(name)">Mohammed</a></td>\\n<td><a',
#  'href="/wiki/Sa%27id"',
#  'class="mw-redirect"',
#  'title="Sa\\\'id">Said</a></td>\\n<td><a',
#  'href="/wiki/Rashid_(name)"',
#  'title="Rashid',
#  '(name)">Rachid</a></td>\\n<td><a',
#  'href="/wiki/Mustafa"',
#  'title="Mustafa">Mustapha</a></td>\\n<td><a',
#  'href="/wiki/Yusuf_(name)"',
#  'class="mw-redirect"',
#  'title="Yusuf',
#  '(name)">Youssef</a></td>\\n<td><a',
#  'href="/wiki/Hassan_(given_name)"',
#  'title="Hassan',
#  '(given',
#  'name)">Hassan</a></td>\\n<td><a',
#  'href="/wiki/Abdus_Salam_(name)"',
#  'title="Abdus',
#  'Salam',
#  '(name)">Abdel-salam</a></td>\\n<td><a',
#  'href="/wiki/Ali_(name)"',
#  'title="Ali',
#  '(name)">Ali</a></td>\\n</tr>\\n<tr>\\n<td><a',
#  'href="/wiki/South_Africa"',
#  'title="South',
#  'Africa">South',
#  'Africa</a><sup',
#  'id="cite_ref-5"',
#  'class="reference"><a',
#  'href="#cite_note-5">[5]</a></sup>',
#  '(2015)</td>\\n<td><a',
#  'href="/wiki/Junior_(name)"',
#  'title="Junior',
#  '(name)">Junior</a></td>\\n<td><a',
#  'href="/wiki/Blessing"',
#  'title="Blessing">Blessing</a></td>\\n<td><a',
#  'href="/wiki/Gift"',
#  'title="Gift">Gift</a></td>\\n<td>Bandile</td>\\n<td><a',
#  'href="/wiki/Prince"',
#  'title="Prince">Prince</a></td>\\n<td>Siyabonga</td>\\n<td>Melokuhle</td>\\n<td>Lethabo</td>\\n<td>Banele</td>\\n<td>Samkelo</td>\\n</tr>\\n<tr>\\n<td><a',
#  'href="/wiki/Tunisia"',
#  'title="Tunisia">Tunisia</a><sup',
#  'id="cite_ref-babynamefacts2005_6-0"',
#  'class="reference"><a',
#  'href="#cite_note-babynamefacts2005-6">[6]</a></sup></td>\\n<td><a',
#  'href="/wiki/Mehdi"',
#  'title="Mehdi">Mehdi</a></td>\\n<td><a',
#  'href="/wiki/Yusuf_(name)"',
#  'class="mw-redirect"',
#  'title="Yusuf',
#  '(name)">Youssef</a></td>\\n<td><a',
#  'href="/wiki/Aziz"',
#  'title="Aziz">Aziz</a></td>\\n<td><a',
#  'href="/wiki/Karim"',
#  'title="Karim">Karim</a></td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n</tr>\\n</table>\\n<h4><span',
#  'class="mw-headline"',
#  'id="Female_names">Female',
#  'names</span><span',
#  'class="mw-editsection"><span',
#  'class="mw-editsection-bracket">[</span><a',
#  'href="/w/index.php?title=List_of_most_popular_given_names&amp;action=edit&amp;section=4"',
#  'title="Edit',
#  'section:',
#  'Female',
#  'names">edit</a><span',
#  'class="mw-editsection-bracket">]</span></span></h4>\\n<table',
#  'class="wikitable">\\n<tr',
#  'style="background:#a0d0ff;">\\n<th',
#  'width="300">Region',
#  '(year)</th>\\n<th>No.',
#  '1</th>\\n<th>No.',
#  '2</th>\\n<th>No.',
#  '3</th>\\n<th>No.',
#  '4</th>\\n<th>No.',
#  '5</th>\\n<th>No.',
#  '6</th>\\n<th>No.',
#  '7</th>\\n<th>No.',
#  '8</th>\\n<th>No.',
#  '9</th>\\n<th>No.',
#  '10</th>\\n</tr>\\n<tr>\\n<td><a',
#  'href="/wiki/Algeria"',
#  'title="Algeria">Algeria</a>',
#  '(census,',
#  '2010)<sup',
#  'id="cite_ref-ine.es_1-2"',
#  'class="reference"><a',
#  'href="#cite_note-ine.es-1">[1]</a></sup></td>\\n<td><a',
#  'href="/wiki/Fatima_(given_name)"',
#  'title="Fatima',
#  '(given',
#  'name)">Fatima</a></td>\\n<td><a',
#  'href="/wiki/Sarah_(given_name)"',
#  'title="Sarah',
#  '(given',
#  'name)">Sara</a></td>\\n<td>Fatiha</td>\\n<td><a',
#  'href="/wiki/A%27isha_(name)"',
#  'title="A\\\'isha',
#  '(name)">Aicha</a></td>\\n<td><a',
#  'href="/wiki/Fatima_(given_name)"',
#  'title="Fatima',
#  '(given',
#  'name)">Fatma</a></td>\\n<td>Amina</td>\\n<td><a',
#  'href="/wiki/Mary_(name)"',
#  'title="Mary',
#  '(name)">Meriem</a></td>\\n<td>Karima</td>\\n<td>Kheira</td>\\n<td>Nadia</td>\\n</tr>\\n<tr>\\n<td><a',
#  'href="/wiki/Egypt"',
#  'title="Egypt">Egypt</a>',
#  '(2004,',
#  'unofficial)<sup',
#  'id="cite_ref-ahram2004_2-2"',
#  'class="reference"><a',
#  'href="#cite_note-ahram2004-2">[2]</a></sup></td>\\n<td><a',
#  'href="/wiki/Shayma"',
#  'title="Shayma">Shaimaa</a>,',
#  '<a',
#  'href="/wiki/Fatima_(given_name)"',
#  'title="Fatima',
#  '(given',
#  'name)">Fatma</a>,',
#  'Maha,',
#  '<a',
#  'href="/wiki/Reem_(given_name)"',
#  'title="Reem',
#  '(given',
#  'name)">Reem</a>,',
#  '<a',
#  'href="/wiki/Farida_(given_name)"',
#  'title="Farida',
#  '(given',
#  'name)">Farida</a>,',
#  '<a',
#  'href="/wiki/Ayah"',
#  'title="Ayah">Aya</a>,',
#  '<a',
#  'href="/wiki/Shahd"',
#  'title="Shahd">Shahd</a>,',
#  '<a',
#  'href="/wiki/Ashraqat"',
#  'title="Ashraqat">Ashraqat</a>,',
#  '<a',
#  'href="/wiki/Sahar_(name)"',
#  'title="Sahar',
#  '(name)">Sahar</a>,',
#  '<a',
#  'href="/wiki/Fatin"',
#  'title="Fatin">Fatin</a>,',
#  '<a',
#  'href="/w/index.php?title=Dalal_(given_name)&amp;action=edit&amp;redlink=1"',
#  'class="new"',
#  'title="Dalal',
#  '(given',
#  'name)',
#  '(page',
#  'does',
#  'not',
#  'exist)">Dalal</a>,',
#  'Doha,',
#  'Fajr,',
#  '<a',
#  'href="/wiki/Suha_(given_name)"',
#  'title="Suha',
#  '(given',
#  'name)">Suha</a>,',
#  '<a',
#  'href="/wiki/Rowan_(name)"',
#  'title="Rowan',
#  '(name)">Rowan</a>,',
#  'Hosniya,',
#  'Hasnaa,',
#  'Hosna,',
#  'Gamila,',
#  'Gamalat,',
#  '<a',
#  'href="/wiki/Habib"',
#  'title="Habib">Habiba</a></td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n</tr>\\n<tr>\\n<td><a',
#  'href="/wiki/Egypt"',
#  'title="Egypt">Egypt</a>',
#  '(2004,',
#  '<a',
#  'href="/wiki/Coptic_Christians"',
#  'class="mw-redirect"',
#  'title="Coptic',
#  'Christians">Coptic',
#  'Christians</a>,',
#  'unofficial)<sup',
#  'id="cite_ref-ahram2004_2-3"',
#  'class="reference"><a',
#  'href="#cite_note-ahram2004-2">[2]</a></sup></td>\\n<td><a',
#  'href="/wiki/Mary_(name)"',
#  'title="Mary',
#  '(name)">Mary,',
#  'Marie,',
#  'Mariam</a>,',
#  '<a',
#  'href="/wiki/Marina_(given_name)"',
#  'title="Marina',
#  '(given',
#  'name)">Marina</a>,',
#  '<a',
#  'href="/wiki/Irene_(given_name)"',
#  'title="Irene',
#  '(given',
#  'name)">Irene</a>,',
#  '<a',
#  'href="/wiki/Malak"',
#  'title="Malak">Malak</a>,',
#  'Habiba,',
#  '<a',
#  'href="/wiki/Hana_(given_name)"',
#  'class="mw-redirect"',
#  'title="Hana',
#  '(given',
#  'name)">Hana</a>,',
#  '<a',
#  'href="/wiki/Farah_(given_name)"',
#  'class="mw-redirect"',
#  'title="Farah',
#  '(given',
#  'name)">Farah</a>,',
#  '<a',
#  'href="/wiki/Marwa_(given_name)"',
#  'title="Marwa',
#  '(given',
#  'name)">Marwa</a>,',
#  'Nada,',
#  '<a',
#  'href="/wiki/Salma"',
#  'title="Salma">Salma</a></td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n<td>NA</td>\\n</tr>\\n<tr>\\n<td><a',
#  ...]

# %%
#Now we want to find how many names start with letter J and T and the length of the name is between 4 and 7 characters
#we started by trying search() function in regular expression lirbrary

import re

for word in words:
    
    if re.search(r'John',word):
        print(word)

#the result is very messy. We have to find other way or libraries to better process web page contents
# Out:
# href="/wiki/John_(given_name)"
# title="John
# name)">John</a>,
# href="/wiki/John_(first_name)"
# title="John
# name)">John</a></td>\n<td><a
# href="/wiki/John_(given_name)"
# title="John
# href="/wiki/John_(given_name)"
# title="John
# href="/wiki/John_(given_name)"
# title="John
# name)">John</a>
# href="/wiki/John_(given_name)"
# title="John
# name)">John</a>
# href="/wiki/John_(name)"
# title="John
# href="/wiki/John_(given_name)"
# title="John
# href="/wiki/John_(given_name)"
# title="John
# href="/wiki/John_(first_name)"
# title="John
# href="/wiki/John_(given_name)"
# title="John
# href="/wiki/John_(given_name)"
# title="John
# href="/wiki/John_(given_name)"
# title="John
# href="/wiki/John_(name)"
# title="John
# (name)">John/Jean/Jonathan/Juan/Gan</a></td>\n<td><a
# href="/wiki/John_(name)"
# title="John
# href="/wiki/John_(given_name)"
# title="John
# href="/wiki/John_(first_name)"
# title="John
# href="/wiki/John_(first_name)"
# title="John
# href="/wiki/John_(first_name)"
# title="John
# href="/wiki/John_(given_name)"
# title="John
# href="http://thepinoy.net/?p=8921">"John
# title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AList+of+most+popular+given+names&amp;rft.btitle=John+Paul%2C+Althea+most+popular+names+for+Pinoy+babies%2C+as+Spanish+names+decline+%BB+Culture&amp;rft.date=2013-06-29&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fthepinoy.net%2F%3Fp%3D8921&amp;rft.pub=thePinoy&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook"

# %%
#Let's try BeautifulSoup library which is another solution for processing data from HTML pages. It has extended capacity of
#reganizing HTML tags and extracting data between tags
from bs4 import BeautifulSoup

#BeautifulSoup usually works with request package hand-in-hand. Requests will open a website as a channel as opening a file 
#for processing. 
import requests

#The following page contains the system vulnerabilities reported by Symantec
#Let's take the content of the page out for processing
url = 'https://www.symantec.com/security_response/landing/vulnerabilities.jsp'

# %%
# Request content from web page
response = requests.get(url)
content = response.content

# %%
soup = BeautifulSoup(content, 'lxml')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Vulnerabilities - Symantec Corp.</title>
# <meta content="en-US" http-equiv="Content-Language"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="Spyware and Adware" name="description"/>
# <meta content="Spyware and Adware, Dialers, Hack tools, Hoaxes, joke programs, trackware" name="keywords"/>
# <meta content="/security_response/landing/vulnerabilities.jsp" name="symc.page"/>
# <meta content="en" name="om.site_language"/>
# <meta content="us" name="om.site_country"/>
# <meta content="html" name="om.content_format"/>
# <meta content="page" name="om.content_type"/>
# <meta content="Vulnerabilities" name="om.content_title"/>
# <meta content="Business" name="om.visitor_segment"/>
# <meta content="Security Response" name="om.visitor_sub_segment"/>
# <meta content="Security Response" name="om.site_section"/>
# <meta content="Security Response" name="om.site_section_us"/>
# <meta content="en/us: biz: security response: vulnerabilities" name="om.page_name"/>
# <link href="/styles/version-3/symantec.css?20161215" media="screen, projection" rel="stylesheet"/>
# <link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.5.0/css/font-awesome.min.css" media="screen, projection" rel="stylesheet"/>
# <link href="/styles/version-3/print.css?20120712" media="print" rel="stylesheet"/>
# <!--[if IE 6]><link href="/styles/version-3/ie1.css?20130412" media="screen, projection" rel="stylesheet"/><![endif]-->
# <!--[if IE 7]><link href="/styles/version-3/ie2.css?20130412" media="screen, projection" rel="stylesheet"/><![endif]-->
# <!--[if IE 8]><link href="/styles/version-3/ie3.css?20130412" media="screen, projection" rel="stylesheet"/><![endif]-->
# <link href="/security_response/landing/vulnerabilities.jsp" rel="canonical"/>
# <script src="/scripts/version-3/rum/rum-min.js?20160204"></script>
# <script src="/scripts/library/jquery-1.7.2.min.js?20140127"></script>
# <script src="//nexus.ensighten.com/symantec/symEnterprise/Bootstrap.js"></script>
# <script src="/script/omniture/om_code.js?20160523"></script>
# <script src="/script/omniture/s_code.js?20160811"></script><script>s.pageName=metaData['page_name'];</script>
# <script src="/scripts/version-3/symantec-min.js?20161209"></script><link href="/styles/version-3/tiptip/tipTip.css?20130111" media="screen, projection" rel="stylesheet"/><script src="/scripts/version-3/tiptip/jquery.tipTip.minified.js?20120813"></script><script src="/scripts/version-3/infobox/infobox.js?20120724"></script><link href="/styles/version-3/infobox/infobox.css?20130111" media="screen, projection" rel="stylesheet"/>
# <link href="/styles/version-3/interim-us.css?20161215" media="screen, projection" rel="stylesheet"/>
# </head>
# <body>
# <a class="hide" href="#startcontent"></a>
# <div class="ssPane fontMD mrgnBtmMD unit bckGry noBorder">
# <div class="ssUtil" style="width:1366px">
# <div class="unitRight">
# <script language="javascript" src="/scripts/version-3/login/aes.js" type="text/javascript"></script>
# <div class="unit" id="hideLoginSAML" style="display: none;">
# <div class="mod-linkSites unit"><div class="auth-login"><a href="https://www.symantec.com/bin/symantec/signin?returnUrl=/partner-landing"><i class="fa fa-lock"></i> Login to PartnerNet</a></div></div>
# </div>
# <div class="unit" id="hideLoggedSAML" style="display: none;">
# <script>
# 			var authVal = getCookie('SymcLogin');
# 			var authString = CryptoJS.AES.decrypt(authVal, "SymcEncryptLogin");
# 			var authCookie = authString.toString(CryptoJS.enc.Utf8);
# 		</script>
# <div class="auth-selector mod-linkSites unit">
# <ul class="flyout auth-nav">
# <li class="auth-menu"><a href="#" onclick="return false;"><i class="fa fa-user"></i> Hi, <script>document.write(authCookie);</script></a>
# <div class="flyoutConnect flyoutAuthConnect hide"></div>
# <div class="flyoutContainer">
# <div class="flyoutContent flyouAuthContent">
# <div class="bckYellow unit" style="padding:1px;">
# <div class="bckSolidWht unit">
# <div class="mod-flyoutContent unit">
# <div class="mod-flyoutContentLft bckSolidWht unit" style="margin-top:20px;">
# <div class="unit">
# <ul class="listNone">
# <li><a href="https://partnernet.symantec.com/portal/faces/home/ManageAccount/MyAccountInfo">My Details</a></li>
# <li><a href="https://partnernet.symantec.com/portal/faces/home/ManageAccount/Overview">Overview</a></li>
# <li><a class="logout" href="https://symaccount.symantec.com/SymAccount/processLogout.do">Logout</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <script type="text/javascript">
# 			$('.logout').click(function(e) {
# 				eraseCookie('SymcLogin');
# 				e.preventDefault();
# 				window.open('https://symaccount.symantec.com/SymAccount/processLogout.do', '_blank');
# 				window.open('https://www.symantec.com/system/sling/logout', '_self');
# 			});
# 		</script>
# </div>
# <div class="mod-linkSites unit">
# <a href="/globalsites/index.jsp" title="Change Country"><i class="fa fa-globe"></i><span>United States</span></a>
# </div>
# </div>
# </div>
# </div>
# <div class="headerPane clear">
# <div class="colOneMain mrgnTopMD mrgnBtmLG clearfix" style="width:1366px;">
# <div class="symLogo unit">
# <a href="/index.jsp"><img alt="Symantec | United States" height="" src="/images/version-3/symantec-logo-top.png" title="Symantec | United States" width=""/></a>
# </div>
# <div class="unitRight bckPadTopMD">
# <div class="bckPadBtmSM unit mrgnRgtLG">
# <div>
# <ul class="flyout" id="flyout">
# <li class="flyoutTitle">
# <a href="/products/" title="Products"> PRODUCTS
#  </a>
# <div class="flyoutConnect hide"></div>
# <div class="flyoutContainer ">
# <div class="flyoutContent">
# <div class="bckPadXSM bckSolidMedGry unit">
# <div class="bckSolidWht unit">
# <div class="mod-flyoutContent unit">
# <div class="mod-flyoutContentLft bckSolidWht bckPadMD unit">
# <div class="unit">
# <ul class="listNone">
# <li><a href="/products/threat-protection">Threat Protection</a></li>
# <li><a href="/products/information-protection">Information Protection</a></li>
# <li><a href="/products/cyber-security-services">Cyber Security Services</a></li>
# <li><a href="https://www.symantec.com/website-security/">Website Security</a></li>
# <li><a href="/products/products-az">Products A-Z</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# </li>
# <li class="flyoutTitle">
# <a href="/services/" title="Services"> SERVICES
#  </a>
# <div class="flyoutConnect hide"></div>
# <div class="flyoutContainer ">
# <div class="flyoutContent">
# <div class="bckPadXSM bckSolidMedGry unit">
# <div class="bckSolidWht unit">
# <div class="mod-flyoutContent unit">
# <div class="mod-flyoutContentLft bckSolidWht bckPadMD unit">
# <div class="unit">
# <ul class="listNone">
# <li><a href="/services/consulting-services">Consulting Services</a></li>
# <li><a href="/services/customer-success-services">Customer Success Service</a></li>
# <li><a href="/services/cyber-security-services">Cyber Security Services</a></li>
# <li><a href="/services/education-services">Education Services</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# </li>
# <li class="flyoutTitle">
# <a href="/solutions/" title="Solutions"> SOLUTIONS
#  </a>
# <div class="flyoutConnect hide"></div>
# <div class="flyoutContainer ">
# <div class="flyoutContent">
# <div class="bckPadXSM bckSolidMedGry unit">
# <div class="bckSolidWht unit">
# <div class="mod-flyoutContent unit">
# <div class="mod-flyoutContentLft bckSolidWht bckPadMD unit">
# <div class="unit">
# <ul class="listNone">
# <li><a href="/solutions/internet-of-things">Internet of Things</a></li>
# <li><a href="/solutions/office365">Office 365</a></li>
# <li><a href="/solutions/automotive">Automotive</a></li>
# <li><a href="/solutions/education">Education</a></li>
# <li><a href="/solutions/federal-gov">Federal Government</a></li>
# <li><a href="/solutions/financial-services">Financial Services</a></li>
# <li><a href="/solutions/global-service">Global Service Providers</a></li>
# <li><a href="/solutions/industrial-control">Industrial Control Systems</a></li>
# <li><a href="/solutions/healthcare">Healthcare</a></li>
# <li><a href="/solutions/retail">Retail</a></li>
# <li><a href="/solutions/state-local-gov">State &amp; Local</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# </li>
# <li class="flyoutTitle">
# <a href="https://support.symantec.com/en_US.html" title="Support Center"> SUPPORT CENTER
#  </a>
# <div class="flyoutConnect hide"></div>
# <div class="flyoutContainer ">
# <div class="flyoutContent">
# <div class="bckPadXSM bckSolidMedGry unit">
# <div class="bckSolidWht unit">
# <div class="mod-flyoutContent unit">
# <div class="mod-flyoutContentLft bckSolidWht bckPadMD unit">
# <div class="unit">
# <ul class="listNone">
# <li><a href="https://support.symantec.com/en_US.html">Technical Support</a></li>
# <li><a href="http://www.symantec.com/connect/">Symantec Connect</a></li>
# <li><a href="/support-center/buying-programs">Buying Programs</a></li>
# <li><a href="/support-center/upgrades">Upgrades</a></li>
# <li><a href="/support-center/renewals">Renewals</a></li>
# <li><a href="/services/education-services">Training</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# </li>
# <li class="flyoutTitle">
# <a href="/security_response/" title="Security Response"> SECURITY CENTER
#  </a>
# <div class="flyoutConnect hide"></div>
# <div class="flyoutContainer ">
# <div class="flyoutContent">
# <div class="bckPadXSM bckSolidMedGry unit">
# <div class="bckSolidWht unit">
# <div class="mod-flyoutContent unit">
# <div class="mod-flyoutContentLft bckSolidWht bckPadMD unit">
# <div class="unit">
# <ul class="listNone">
# <li><a href="http://www.symantec.com/connect/symantec-blogs/symantec-security-response">Blogs</a></li>
# <li><a href="http://www.symantec.com/security_response/publications/threatreport.jsp">ISTR</a></li>
# <li><a href="http://www.symantec.com/security_response/landing/threats.jsp">Threats</a></li>
# <li><a href="https://www.symantec.com/security_response/definitions.jsp">Virus Definitions and Security Updates</a></li>
# <li><a href="http://www.symantec.com/security_response/removaltools.jsp">Removal Tools</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# </li>
# <li class="flyoutTitle">
# <a href="https://partnernet.symantec.com" title="Partner"> PARTNER
#  </a>
# <div class="flyoutConnect hide"></div>
# <div class="flyoutContainer ">
# <div class="flyoutContent">
# <div class="bckPadXSM bckSolidMedGry unit">
# <div class="bckSolidWht unit">
# <div class="mod-flyoutContent unit">
# <div class="mod-flyoutContentLft bckSolidWht bckPadMD unit">
# <div class="unit">
# <ul class="listNone">
# <li><a href="http://partnerlocator.symantec.com/">Find a Partner</a></li>
# <li><a href="https://partnernet.symantec.com/portal/faces/programs">Become a Partner</a></li>
# </ul>
# <h4>Login Required</h4>
# <ul class="listNone">
# <li><a href="https://partnernet.symantec.com/">Login into Partner Portal</a></li>
# <li>Partner Licensing</li>
# <li>Partner Renewals</li>
# <li>Partner Training</li>
# <li>Margin Builder</li>
# <li>Opportunity Registration</li>
# <li>Financial Benefits</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# </li>
# </ul> </div>
# </div>
# <div class="symUtil unitRight">
# <div class="mod-search unit">
# <a class="show-search " href="/search.html"><i class="fa fa-search"></i></a>
# </div>
# </div> </div> </div>
# <div class="clear"></div>
# </div>
# <a id="startcontent"></a>
# <!--ng-->
# <div class="contentPane megaNav">
# <div class="cbMrgnBtmMD cbMrgnTopSM">
# <div class="unit colTwoStyle11">
# <ol class="crumbs">
# <li><a href="/index.jsp"><img alt="Symantec" height="10" src="/images/version-3/icons/home-icon.png" width="11"/><span>/</span></a></li><li><a href="/security_response/">Security Response</a><span>/</span></li>
# <li>Vulnerabilities</li>
# </ol>
# </div>
# <div class="unitRight colTwoStyle21">
# <div class="unitRight">
# <div class="utilNav unit">
# <ul class="unit">
# <li class="addAction">
# <div><span class="addTitle">
# 					Add
# 					</span>
# <div class="transitionSmall hide"></div>
# </div>
# </li>
# </ul>
# <div class="utilMenu mod-add-dropdown relative clear hide upperzIndex">
# <ul class="addItems unit trackSBOmniture" data-omniture="sb_widget_small">
# <li>	Add Bookmark or Share
# 	</li>
# <li><img alt="Google+" src="/content/en/us/global/images/version3/social-media-icons/google-plus.png"/><a class="pixCon4434" href="https://plus.google.com/share?url=THE_PAGE_URL" target="_blank" title="Google+">Google+</a></li>
# <div class="hr"></div>
# <li><img alt="Technorati" src="/content/en/us/global/images/utilityicons/socialbookmark/logos/technorati-logo.gif"/><a class="pixCon3106" href="http://technorati.com/faves?add=THE_PAGE_URL&amp;title=THE_PAGE_TITLE" target="_blank" title="Technorati">Technorati</a></li>
# <div class="hr"></div>
# <li><img alt="Digg" src="/content/en/us/global/images/utilityicons/socialbookmark/logos/digg-logo.gif"/><a class="pixCon3100" href="http://digg.com/submit?url=THE_PAGE_URL&amp;title=THE_PAGE_TITLE" target="_blank" title="Digg">Digg</a></li>
# <div class="hr"></div>
# <li><img alt="Delicious" src="/content/en/us/global/images/utilityicons/socialbookmark/logos/delicious-logo.gif"/><a class="pixCon3099" href="http://del.icio.us/post?url=THE_PAGE_URL&amp;title=THE_PAGE_TITLE" target="_blank" title="Delicious">Delicious</a></li>
# <div class="hr"></div>
# <li><img alt="Reddit" src="/content/en/us/global/images/utilityicons/socialbookmark/logos/reddit-logo.gif"/><a class="pixCon3104" href="http://reddit.com/submit?url=THE_PAGE_URL&amp;title=THE_PAGE_TITLE" target="_blank" title="Reddit">Reddit</a></li>
# <div class="hr"></div>
# <li><img alt="StumbleUpon" src="/content/en/us/global/images/utilityicons/socialbookmark/logos/stumbleupon-logo.gif"/><a class="pixCon3105" href="http://www.stumbleupon.com/submit?url=THE_PAGE_URL&amp;title=THE_PAGE_TITLE" target="_blank" title="StumbleUpon">StumbleUpon</a></li>
# <div class="hr"></div>
# <li><img alt="Twitter" src="/content/en/us/global/images/utilityicons/socialbookmark/logos/twitter.gif"/><a class="pixCon3107" href="http://twitter.com/home?status=THE_PAGE_TITLE+THE_PAGE_URL" target="_blank" title="Twitter">Twitter</a></li>
# <div class="hr"></div>
# <li><img alt="LinkedIn" src="/content/en/us/global/images/utilityicons/socialbookmark/logos/linkedin-logo.gif"/><a href="http://www.linkedin.com/shareArticle?mini=true&amp;url=THE_PAGE_URL&amp;title=THE_PAGE_TITLE" target="_blank" title="LinkedIn">LinkedIn</a></li>
# <div class="hr"></div>
# <li><img alt="Facebook" src="/content/en/us/global/images/utilityicons/socialbookmark/logos/facebook.gif"/><a class="pixCon3101" href="http://www.facebook.com/share.php?u=THE_PAGE_URL&amp;t=THE_PAGE_TITLE" target="_blank" title="Facebook">Facebook</a></li>
# <div class="hr"></div>
# <li><img alt="Newsvine" src="/content/en/us/global/images/utilityicons/socialbookmark/logos/newsvine-logo.gif"/><a class="pixCon3103" href="http://www.newsvine.com/_wine/save?popoff=0&amp;url=THE_PAGE_URL&amp;title=THE_PAGE_TITLE" target="_blank" title="Newsvine">Newsvine</a></li>
# </ul> </div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div> <h1> Security Response
#  </h1>
# <div class="colTwoMain unit">
# <div class="bckBrdr bckGry unit">
# <div class="bckPadSmall introTxt1">
#         Our security research centers around the world provide unparalleled analysis of and protection from IT security threats that include malware, security risks, vulnerabilities, and spam.
#
#       </div>
# <div class="tabs1">
# <ul class="clearfix tabsNav">
# <li class="unit"><a href="/security_response/index.jsp">Overview</a></li>
# <li class="unit"><a href="/security_response/landing/threats.jsp">Threats</a></li>
# <li class="unit"><a href="/security_response/landing/risks/index.jsp">Risks</a></li>
# <li class="unit"><a class="on" href="/security_response/landing/vulnerabilities.jsp">Vulnerabilities</a></li>
# <li class="unit"><a href="/security_response/landing/spam/index.jsp">Spam</a></li>
# <li class="unit"><a href="/security_response/landing/azlisting.jsp">A-Z</a></li>
# </ul>
# <div class="bckSolidBlk bckBrdr clearfix" id="tab1">
# <div class="bckSolidGry bckBrdr clearfix">
# <div class="bckSolidWht bckPadLarge clearfix">
# <div><strong>
# <a href="/business/security_response/securityupdates/list.jsp?fid=security_advisory" title="Security Advisory List for Symantec Products">Security Advisory List for Symantec Products</a>
# </strong></div>
# <div class="mrgnMD">
# <div class="unit">
# <h3>
#                     Vulnerabilities
#                   </h3>
# </div>
# <div class="unit">
# <div class="infobox" id="infobox">
# <div class="infoboxIcon"><img alt="?" src="/images/version-3/icons/green-info-icon.png" title="?"/></div>
# <div class="tooltipTopWrap tooltip hide" id="vulnerabilities">
# <div class="tooltipTopImage"><img alt="" src="/images/version-3/arrows/pop-up-up-white-arrows.png" title=""/></div>
# <div class="tooltipTopBody">
# 			A Vulnerability is a state in a computing system (or set of systems) which either (a) allows an attacker to execute commands as another user, (b) allows an attacker to access data that is contrary to the specified access restrictions for that data, (c) allows an attacker to pose as another entity, or (d) allows an attacker to conduct a denial of service. <p></p>
#         Advisories relating to Symantec products may be viewed <a href="/business/security_response/securityupdates/list.jsp?fid=security_advisory">here</a>.
# 	</div> </div>
# </div>
# </div>
# <div class="unitRight"><a href="/xml/rss/listings.jsp?lid=advisories"><img alt="Subscribe" src="/images/masthead/button-rss-square-md.gif" title="Subscribe"/></a></div>
# <div class="clear"></div>
# </div>
# <table class="defaultTableStyle tableFontMD tableNoBorder">
# <thead>
# <tr>
# <td class="bckSolidDrkGry smallTdPadding">Severity</td><td class="bckSolidDrkGry">Name</td><td class="bckSolidDrkGry">Discovered</td>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=91105" title="Microsoft Internet Explorer XSS Filter CVE-2016-3212 Security Bypass Vulnerability">Microsoft Internet Explorer XSS Filter CVE-2016-3212 Security Bypass Vulnerabili...</a></td><td>06/14/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=95425" title="Microsoft Identity Model Extensions Token Signing Verification Privilege Escalation Vulnerability">Microsoft Identity Model Extensions Token Signing Verification Privilege Escalat...</a></td><td>01/10/2017</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=95318" title="Microsoft Windows LSASS CVE-2017-0004 Denial of Service Vulnerability">Microsoft Windows LSASS CVE-2017-0004 Denial of Service Vulnerability</a></td><td>01/10/2017</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94064" title="Microsoft Windows Kernel 'Win32k.sys' CVE-2016-7255 Local Privilege Escalation Vulnerability">Microsoft Windows Kernel 'Win32k.sys' CVE-2016-7255 Local Privilege Escalation V...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=95287" title="Microsoft Office CVE-2017-0003 Memory Corruption Vulnerability">Microsoft Office CVE-2017-0003 Memory Corruption Vulnerability</a></td><td>01/10/2017</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=95284" title="Microsoft Edge CVE-2017-0002 Remote Privilege Escalation Vulnerability">Microsoft Edge CVE-2017-0002 Remote Privilege Escalation Vulnerability</a></td><td>01/10/2017</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94741" title="Microsoft .NET Framework CVE-2016-7270 Information Disclosure Vulnerability">Microsoft .NET Framework CVE-2016-7270 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="2" src="/images/version-3/level2.png" title="2"/></td><td><a href="/security_response/vulnerability.jsp?bid=94787" title="Microsoft Windows CVE-2016-7295 Local Information Disclosure Vulnerability">Microsoft Windows CVE-2016-7295 Local Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94768" title="Microsoft Windows Installer CVE-2016-7292 DLL Loading Local Privilege Escalation Vulnerability">Microsoft Windows Installer CVE-2016-7292 DLL Loading Local Privilege Escalation...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="2" src="/images/version-3/level2.png" title="2"/></td><td><a href="/security_response/vulnerability.jsp?bid=94764" title="Microsoft Windows Crypto Driver CVE-2016-7219 Local Information Disclosure Vulnerability">Microsoft Windows Crypto Driver CVE-2016-7219 Local Information Disclosure Vulne...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94877" title="Adobe Flash Player APSB16-39 Unspecified Use After Free Remote Code Execution Vulnerability">Adobe Flash Player APSB16-39 Unspecified Use After Free Remote Code Execution Vu...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94668" title="Microsoft Office CVE-2016-7263 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7263 Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94662" title="Microsoft Office CVE-2016-7266 Remote Code Execution Vulnerability">Microsoft Office CVE-2016-7266 Remote Code Execution Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94664" title="Microsoft Office CVE-2016-7267 Security Bypass Vulnerability">Microsoft Office CVE-2016-7267 Security Bypass Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94672" title="Microsoft Office CVE-2016-7268 Information Disclosure Vulnerability">Microsoft Office CVE-2016-7268 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94665" title="Microsoft Office CVE-2016-7275 DLL Loading Remote Code Execution Vulnerability">Microsoft Office CVE-2016-7275 DLL Loading Remote Code Execution Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94666" title="Microsoft Office CVE-2016-7276 Information Disclosure Vulnerability">Microsoft Office CVE-2016-7276 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94670" title="Microsoft Office CVE-2016-7290 Information Disclosure Vulnerability">Microsoft Office CVE-2016-7290 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94771" title="Microsoft Windows Graphics Component CVE-2016-7259 Local Privilege Escalation Vulnerability">Microsoft Windows Graphics Component CVE-2016-7259 Local Privilege Escalation Vu...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94671" title="Microsoft Office CVE-2016-7291 Information Disclosure Vulnerability">Microsoft Office CVE-2016-7291 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94660" title="Microsoft Office CVE-2016-7262 Remote Code Execution Vulnerability">Microsoft Office CVE-2016-7262 Remote Code Execution Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94785" title="Microsoft Windows Kernel 'Win32k.sys' CVE-2016-7260 Local Privilege Escalation Vulnerability">Microsoft Windows Kernel 'Win32k.sys' CVE-2016-7260 Local Privilege Escalation V...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94722" title="Microsoft Internet Explorer and Edge CVE-2016-7287 Remote Memory Corruption Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7287 Remote Memory Corruption Vuln...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94752" title="Microsoft Windows Graphics Component CVE-2016-7273 Remote Code Execution Vulnerability">Microsoft Windows Graphics Component CVE-2016-7273 Remote Code Execution Vulnera...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94739" title="Microsoft Windows Graphics Component CVE-2016-7272 Remote Code Execution Vulnerability">Microsoft Windows Graphics Component CVE-2016-7272 Remote Code Execution Vulnera...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94751" title="Microsoft Edge CVE-2016-7297 Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-7297 Remote Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94750" title="Microsoft Edge CVE-2016-7280 Information Disclosure Vulnerability">Microsoft Edge CVE-2016-7280 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94724" title="Microsoft Internet Explorer and Edge CVE-2016-7282 Information Disclosure Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7282 Information Disclosure Vulner...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94723" title="Microsoft Internet Explorer and Edge CVE-2016-7281 Security Bypass Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7281 Security Bypass Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94784" title="Microsoft Auto Updater for Mac CVE-2016-7300 Local Privilege Escalation Vulnerability">Microsoft Auto Updater for Mac CVE-2016-7300 Local Privilege Escalation Vulnerab...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94715" title="Microsoft Office CVE-2016-7277 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7277 Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94719" title="Microsoft Internet Explorer and Edge CVE-2016-7279 Remote Memory Corruption Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7279 Remote Memory Corruption Vuln...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="2" src="/images/version-3/level2.png" title="2"/></td><td><a href="/security_response/vulnerability.jsp?bid=94736" title="Microsoft Windows Kernel CVE-2016-7258 Local Information Disclosure Vulnerability">Microsoft Windows Kernel CVE-2016-7258 Local Information Disclosure Vulnerabilit...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94734" title="Microsoft Windows CVE-2016-7271 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-7271 Local Privilege Escalation Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94721" title="Microsoft Office CVE-2016-7265 Information Disclosure Vulnerability">Microsoft Office CVE-2016-7265 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94769" title="Microsoft Office CVE-2016-7264 Information Disclosure Vulnerability">Microsoft Office CVE-2016-7264 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94718" title="Microsoft Office CVE-2016-7289 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7289 Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94720" title="Microsoft Office CVE-2016-7298 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7298 Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94758" title="Microsoft Windows Uniscribe CVE-2016-7274 Remote Code Execution Vulnerability">Microsoft Windows Uniscribe CVE-2016-7274 Remote Code Execution Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94748" title="Microsoft Edge CVE-2016-7286 Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-7286 Remote Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94749" title="Microsoft Edge CVE-2016-7288 Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-7288 Remote Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94738" title="Microsoft Edge CVE-2016-7296 Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-7296 Remote Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94737" title="Microsoft Edge CVE-2016-7206 Information Disclosure Vulnerability">Microsoft Edge CVE-2016-7206 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94735" title="Microsoft Edge CVE-2016-7181 Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-7181 Remote Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94755" title="Microsoft Windows Graphics Component CVE-2016-7257 Information Disclosure Vulnerability">Microsoft Windows Graphics Component CVE-2016-7257 Information Disclosure Vulner...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94725" title="Microsoft Internet Explorer CVE-2016-7284 Information Disclosure Vulnerability">Microsoft Internet Explorer CVE-2016-7284 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94726" title="Microsoft Internet Explorer CVE-2016-7283 Remote Memory Corruption Vulnerability">Microsoft Internet Explorer CVE-2016-7283 Remote Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94716" title="Microsoft Internet Explorer CVE-2016-7278 Information Disclosure Vulnerability">Microsoft Internet Explorer CVE-2016-7278 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94042" title="Microsoft Edge CVE-2016-7202 Scripting Engine Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-7202 Scripting Engine Remote Memory Corruption Vulnerabi...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94063" title="Microsoft Windows Kernel 'Win32k.sys' CVE-2016-7246 Local Privilege Escalation Vulnerability">Microsoft Windows Kernel 'Win32k.sys' CVE-2016-7246 Local Privilege Escalation V...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94000" title="Microsoft Windows Kernel 'Win32k.sys' CVE-2016-7215 Local Privilege Escalation Vulnerability">Microsoft Windows Kernel 'Win32k.sys' CVE-2016-7215 Local Privilege Escalation V...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94156" title="Microsoft Windows Open Type Font CVE-2016-7256 Remote Code Execution Vulnerability">Microsoft Windows Open Type Font CVE-2016-7256 Remote Code Execution Vulnerabili...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94066" title="Microsoft Windows Media Foundation CVE-2016-7217 Memory Corruption Vulnerability">Microsoft Windows Media Foundation CVE-2016-7217 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94033" title="Microsoft Windows Animation Manager CVE-2016-7205 Memory Corruption Vulnerability">Microsoft Windows Animation Manager CVE-2016-7205 Memory Corruption Vulnerabilit...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94030" title="Microsoft Windows Open Type Font CVE-2016-7210 Information Disclosure Vulnerability">Microsoft Windows Open Type Font CVE-2016-7210 Information Disclosure Vulnerabil...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94056" title="Microsoft SQL Server CVE-2016-7253 Privilege Escalation Vulnerability">Microsoft SQL Server CVE-2016-7253 Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94050" title="Microsoft SQL Server CVE-2016-7252 Information Disclosure Vulnerability">Microsoft SQL Server CVE-2016-7252 Information Disclosure Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94043" title="Microsoft SQL Server Master Data Services CVE-2016-7251 Cross Site Scripting Vulnerability">Microsoft SQL Server Master Data Services CVE-2016-7251 Cross Site Scripting Vul...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94061" title="Microsoft SQL Server CVE-2016-7254 Privilege Escalation Vulnerability">Microsoft SQL Server CVE-2016-7254 Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94060" title="Microsoft SQL Server CVE-2016-7250 Privilege Escalation Vulnerability">Microsoft SQL Server CVE-2016-7250 Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94037" title="Microsoft SQL Server CVE-2016-7249 Privilege Escalation Vulnerability">Microsoft SQL Server CVE-2016-7249 Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94029" title="Microsoft Office CVE-2016-7244 Denial of Service Vulnerability">Microsoft Office CVE-2016-7244 Denial of Service Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94020" title="Microsoft Office CVE-2016-7234 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7234 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94022" title="Microsoft Office CVE-2016-7235 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7235 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94031" title="Microsoft Office CVE-2016-7233 Information Disclosure Vulnerability">Microsoft Office CVE-2016-7233 Information Disclosure Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94025" title="Microsoft Office CVE-2016-7236 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7236 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=93993" title="Microsoft Office CVE-2016-7213 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7213 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=93994" title="Microsoft Office CVE-2016-7228 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7228 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94026" title="Microsoft Office CVE-2016-7245 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7245 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=93996" title="Microsoft Office CVE-2016-7231 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7231 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94005" title="Microsoft Office CVE-2016-7232 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7232 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=93995" title="Microsoft Office CVE-2016-7229 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7229 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94018" title="Microsoft Windows CVE-2016-7226 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-7226 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94015" title="Microsoft Windows CVE-2016-7184 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-7184 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94055" title="Microsoft Internet Explorer and Edge CVE-2016-7241 Remote Memory Corruption Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7241 Remote Memory Corruption Vuln...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94053" title="Microsoft Internet Explorer and Edge CVE-2016-7198 Remote Memory Corruption Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7198 Remote Memory Corruption Vuln...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94065" title="Microsoft Internet Explorer and Edge CVE-2016-7227 Information Disclosure Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7227 Information Disclosure Vulner...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94007" title="Microsoft Windows CVE-2016-3343 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-3343 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94057" title="Microsoft Internet Explorer and Edge CVE-2016-7199 Information Disclosure Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7199 Information Disclosure Vulner...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94052" title="Microsoft Internet Explorer and Edge CVE-2016-7195 Remote Memory Corruption Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7195 Remote Memory Corruption Vuln...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94051" title="Microsoft Internet Explorer and Edge CVE-2016-7196 Remote Memory Corruption Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7196 Remote Memory Corruption Vuln...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94059" title="Microsoft Edge and Internet Explorer XSS Filter CVE-2016-7239 Information Disclosure Vulnerability">Microsoft Edge and Internet Explorer XSS Filter CVE-2016-7239 Information Disclo...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94013" title="Microsoft Windows CVE-2016-3342 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-3342 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# ...
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=2049" title="Quikstore File Disclosure Vulnerability">Quikstore File Disclosure Vulnerability</a></td><td>11/20/2000</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="2" src="/images/version-3/level2.png" title="2"/></td><td><a href="/security_response/vulnerability.jsp?bid=1959" title="Joe Text Editor DEADJOE Symbolic Link Vulnerability">Joe Text Editor DEADJOE Symbolic Link Vulnerability</a></td><td>11/16/2000</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="2" src="/images/version-3/level2.png" title="2"/></td><td><a href="/security_response/vulnerability.jsp?bid=1943" title="Kenny Carruthers Postmaster 1.0 Buffer Overflow Vulnerability">Kenny Carruthers Postmaster 1.0 Buffer Overflow Vulnerability</a></td><td>11/14/2000</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="2" src="/images/version-3/level2.png" title="2"/></td><td><a href="/security_response/vulnerability.jsp?bid=1920" title="McAfee VirusScan 4.5 Unquoted ImagePath Vulnerability">McAfee VirusScan 4.5 Unquoted ImagePath Vulnerability</a></td><td>11/03/2000</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=1780" title="Microsoft Windows 9x / Me Share Level Password Bypass Vulnerability">Microsoft Windows 9x / Me Share Level Password Bypass Vulnerability</a></td><td>10/10/2000</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=1781" title="Microsoft Windows 9x / Me IPX NMPI Packet DoS Vulnerability">Microsoft Windows 9x / Me IPX NMPI Packet DoS Vulnerability</a></td><td>10/10/2000</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=1671" title="Microsoft WebTV DoS Vulnerability">Microsoft WebTV DoS Vulnerability</a></td><td>09/12/2000</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=1466" title="Microsoft SQL Server Enterprise Manager Password Disclosure Vulnerability">Microsoft SQL Server Enterprise Manager Password Disclosure Vulnerability</a></td><td>07/11/2000</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=1451" title="Microsoft Excel 97 / 2000 Register.ID Vulnerability">Microsoft Excel 97 / 2000 Register.ID Vulnerability</a></td><td>07/11/2000</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=2126" title="iCat Carbo Server File Disclosure Vulnerability">iCat Carbo Server File Disclosure Vulnerability</a></td><td>11/08/1997</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=2078" title="OReilly WebSite 1.x/2.0 win-c-sample.exe Buffer Overflow Vulnerability">OReilly WebSite 1.x/2.0 win-c-sample.exe Buffer Overflow Vulnerability</a></td><td>01/06/1997</td>
# </tr>
# </tbody>
# </table>
# <sub class="fontSM txtLgtGray mrgnTopMD">
#               *For continued protection, make sure that your Symantec <a href="http://service1.symantec.com/Support/custserv.nsf/docid/2004051810092946?OpenDocument&amp;seg=hm&amp;lg=en&amp;ct=us">subscription</a> and/or <a href="/business/licensing/index.jsp">license</a> are up to date.
#               </sub>
# <div style="clear:both"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="colSide unitRight">
# <div class="imgMrgnBtmMD">
# <div class="bckGryBorder textCenter">
# <div class="bckSolidWht colContentThreatCon">
# <h3>THREATCON</h3>
# <a href="#" onclick="javascript:window.open('/security_response/threatconlearn.jsp','learnabout','resizable,scrollbars,height=550,width=420,location=yes')">Level 1: Normal<img alt="ThreatCon Level 1: Normal" class="mrgnSM" src="/images/version-3/threatcon/threatcon-level1.gif" title="ThreatCon Level 1: Normal"/></a>
# <div><strong><a href="/security_response/index.jsp">All Viruses &amp; Risks</a></strong></div>
# </div>
# </div>
# </div>
# <div class="bckSolidGry bckBrdr imgMrgnBtmMD">
# <div class="bckSolidWht bckPadMD fontSM">
# <div class="colTwoStyle34 unit">
# <h3>
# 						Threat Intelligence
# 					</h3>
# </div>
# <div class="unitRight">
# <a href="https://twitter.com/threatintel?ref_src=twsrc%5Etfw"><img align="top" alt="Subscribe" class="imgMrgnLftMD" src="/images/masthead/b-twitter-logo.gif" title="Subscribe"/></a></div>
# <div class="clear"></div>
# <a class="twitter-timeline" data-chrome="nofooter noheader noborders transparent" data-tweet-limit="3" data-widget-id="428828819189796864" href="https://twitter.com/threatintel" width="166">Threat Intelligence</a>
# <script>!function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0],p=/^http:/.test(d.location)?'http':'https';if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src=p+"://platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");</script>
# <strong><a href="http://twitter.com/#!/threatintel" target="_blank">Follow the Threat Intelligence Twitter feed</a></strong>
# </div>
# <div style="clear:both"></div>
# </div>
# <div class="bckSolidGry bckBrdr imgMrgnBtmMD">
# <div class="bckSolidWht bckPadMD fontSM">
# <div class="colTwoStyle34 unit">
# <h3>Response Blogs</h3>
# </div>
# <div class="unitRight"><a href="http://www.symantec.com/connect/blogs/feed/srblog/2261/all/en"> <img alt="Subscribe" class="imgMrgnLftMD" src="/images/masthead/button-rss-square-md.gif" title="Subscribe"/></a></div>
# <div class="clear"></div>
# <div class="mrgnTopMD">
# <div class="mrgnMD">
# <div class="mrgnMD">
# <div><a href="https://www.symantec.com/connect/blogs/greenbug-cyberespionage-group-targeting-middle-east-possible-links-shamoon">Greenbug cyberespionage group targeting Middle East, possible links to Shamoon</a></div> <div>5:58 AM  2017-01-23</div> </div>
# <div class="mrgnMD">
# <div><a href="https://www.symantec.com/connect/blogs/microsoft-patch-tuesday-january-2017">Microsoft Patch Tuesday – January 2017</a></div> <div>11:08 AM  2017-01-10</div> </div>
# <div class="mrgnMD">
# <div><a href="https://www.symantec.com/connect/blogs/airport-boarding-gate-display-leaks-booking-codes-puts-passenger-data-risk">Airport boarding gate display leaks booking codes, puts passenger data at risk</a></div> <div>5:58 AM  2017-01-10</div> </div>
# </div>
# <div class="clear"></div>
# <strong><a href="http://www.symantec.com/connect/symantec-blogs/symantec-security-response">Visit the Security Response Blogs on Symantec Connect</a></strong>
# </div>
# </div>
# <div style="clear:both"></div>
# </div>
# <div class="promoWdgt mrgnTopMD">
# </div>
# <div class="promoWdgt mrgnTopMD">
# <a href="/security_response/publications/threatreport.jsp"><img alt="Internet Security Threat Report, Vol 21" class="imgFltTop" height="190" src="/content/en/us/enterprise/images/promo/istr.png" title="Internet Security Threat Report, Vol 21" width="180"/></a>
# </div>
# <div class="promoWdgt mrgnTopMD">
# <a href="/page.jsp?id=star"><img alt="STAR Antimalware Protection Technologies" class="imgFltTop" height="130" src="/content/en/us/enterprise/images/promo/b-star-technologies-promo.png" title="STAR Antimalware Protection Technologies" width="180"/></a>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# <div class="footerPane">
# <div class="colOneMain">
# <div class="symLogo mrgnTopXLG mrgnBtmMD unit">
# <a href="/index.jsp"><img alt="Symantec | United States" src="/images/version-3/symantec-logo-120x32.png" title="Symantec | United States"/></a>
# </div>
# <div class="unit mrgnBtmXLG fatFooter">
# <div class="mrgnRgtXXXLG txtWidgetFacet unit">
# <h4>INFORMATION FOR:</h4>
# <ul class="listNone">
# <li><a href="https://www.symantec.com/">Enterprise</a></li>
# <li><a href="https://www.symantec.com/content/symantec/english/en/small-business">Small Business</a></li>
# <li><a href="http://us.norton.com/">Consumer (Norton)</a></li>
# <li><a href="https://www.symantec.com/content/symantec/english/en/partners">Partners</a></li>
# </ul>
# </div>
# <div class="mrgnRgtXXXLG txtWidgetFacet unit">
# <h4>OUR OFFERINGS:</h4>
# <ul class="listNone">
# <li><a href="https://www.symantec.com/content/symantec/english/en/products">Products</a></li>
# <li><a href="https://www.symantec.com/content/symantec/english/en/products/products-az">Products A-Z</a></li>
# <li><a href="https://www.symantec.com/content/symantec/english/en/services">Services</a></li>
# <li><a href="https://www.symantec.com/content/symantec/english/en/solutions">Solutions</a></li>
# </ul>
# </div>
# <div class="mrgnRgtXXXLG txtWidgetFacet unit">
# <h4>CONNECT WITH US:</h4>
# <ul class="listNone">
# <li><a href="https://support.symantec.com/">Support</a></li>
# <li><a href="https://www.symantec.com/connect/">Connect Communities</a></li>
# <li><a href="https://www.symantec.com/content/symantec/english/en/security_response">Security Center</a></li>
# <li><a href="http://partnerlocator.symantec.com/">Find a Partner</a></li>
# <li><a href="https://www.symantec.com/content/symantec/english/en/about/events">Events</a></li>
# <li><a href="https://www.symantec.com/content/symantec/english/en/about/webcasts">Webcasts</a></li>
# <li><a href="https://www.symantec.com/content/symantec/english/en/contact-us">Contact Us</a></li>
# </ul>
# </div>
# <div class="mrgnRgtXXXLG txtWidgetFacet unit">
# <h4><a href="https://www.symantec.com/content/symantec/english/en/about">ABOUT SYMANTEC</a></h4>
# <ul class="listNone">
# <li><a href="https://www.symantec.com/content/symantec/english/en/about/customerone">CustomerOne</a></li>
# <li><a href="https://www.symantec.com/content/symantec/english/en/products/performance-center">Performance Center</a></li>
# <li><a href="https://www.symantec.com/content/symantec/english/en/about/newsroom">Newsroom</a></li>
# <li><a href="https://www.symantec.com/content/symantec/english/en/about/careers">Careers</a></li>
# <li><a href="http://investor.symantec.com/About/Investors/default.aspx">Investor Relations</a></li>
# <li><a href="https://www.symantec.com/content/symantec/english/en/about/corporate-responsibility">Corporate Responsibility</a></li>
# <li><a href="https://www.symantec.com/content/symantec/english/en/theme/blue-coat-acquisition">Blue Coat Acquisition</a></li>
# </ul>
# </div>
# <div class="txtWidgetFacet unit">
# </div> </div>
# <div class="unit fullWidth">
# </div>
# <div class="unitRight mrgnTopXLG mrgnBtmLG">
# <div class="unit mrgnRgtLG bckPadTopLG">
# <div class="unit">
# <div class="unit clearfix">
# <ul class=" trackSBOmniture">
# <li class="mrgnRgtMD unit"><a href="http://twitter.com/symantec" target="_blank" title="Twitter"><img alt="Twitter" src="/content/en/us/global/images/version3/social-media-icons/social-twitter-33x33.png"/></a></li>
# <li class="mrgnRgtMD unit"><a href="http://www.facebook.com/Symantec" target="_blank" title="Facebook"><img alt="Facebook" src="/content/en/us/global/images/version3/social-media-icons/social-facebook-33x33.png"/></a></li>
# <li class="mrgnRgtMD unit"><a href="https://www.linkedin.com/company/1231" target="_blank" title="LinkedIn"><img alt="LinkedIn" src="/content/en/us/global/images/version3/social-media-icons/social-linkedin-33x33.png"/></a></li>
# <li class="mrgnRgtMD unit"><a href="https://plus.google.com/+symantec/posts" target="_blank" title="Google+"><img alt="Google+" src="/content/en/us/global/images/version3/social-media-icons/social-googleplus-33x33.png"/></a></li>
# <li class="mrgnRgtMD unit"><a href="https://www.youtube.com/user/symantec/home" target="_blank" title="YouTube"><img alt="YouTube" src="/content/en/us/global/images/version3/social-media-icons/social-youtube-33x33.png"/></a></li>
# </ul> </div>
# </div> </div> <div class="unitRight">
# <script src="/scripts/getverisignsealimage-min.js?20160421"></script>
# </div>
# </div> </div>
# <div class="fullWidth bckYellow unit">
# <div class="footer">
# <div class="">
# 		©1995 - 2017 Symantec Corporation 	</div><div class="">
# <ul class="footerNav">
# <li><a href="/about/" title="About Symantec">About Symantec</a><span>|</span></li><li><a href="/about/careers/" title="Careers">Careers</a><span>|</span></li><li><a href="https://symantecevents.verite.com/?action=public.dsp_calendar&amp;view=list" title="Events">Events</a><span>|</span></li><li><a href="/about/newsroom/" title="News">News</a><span>|</span></li><li><a href="/site-map/" title="Site Map">Site Map</a><span>|</span></li><li><a href="/about/legal/repository/" title="Legal Repository">Legal Repository</a><span>|</span></li><li><a href="/privacy/" title="Privacy">Privacy</a><span>|</span></li><li><a href="/privacy/#about_cookies" title="Cookies">Cookies</a><span>|</span></li><li><a href="/contact-us/" title="Contact">Contact</a></li>
# </ul> </div> </div> </div>
# </div>
# <script src="/scripts/version-3/search/google-min.js?20120403"></script>
# <!--om-->
# <!-- SiteCatalyst code. Copyright 1997-2008 Omniture, Inc. More info available at http://www.omniture.com -->
# <script><!--
#         /* You may give each page an identifying name, server, and channel on the next lines. */
#         s.server="symantec"
#         s.channel=metaData['visitor_segment'] + ': ' + metaData['site_section']
#         s.prop2=metaData['site_country']
#         s.prop3=metaData['site_language']
#         s.prop27=metaData['visitor_segment']
#         s.prop30=metaData['user_id']
#         s.prop41=metaData['site_section']
#         s.prop42=metaData['product_name']
#         s.prop43=metaData['product_category_name']
#         s.prop44=metaData['product_sub_category_name']
#         s.prop45=metaData['product_version_name']
#         s.prop46=metaData['content_format']
#         s.prop47=metaData['content_type']
#         s.prop48=metaData['content_title']
#         s.prop49=metaData['site_sub_section']
#         s.prop54=metaData['site_section_us']
#         s.prop58=metaData['site_sub_sub_section']
#         s.prop64=metaData['visitor_sub_segment']
#         s.prop52=metaData['site_section_4']
#         s.prop53=metaData['site_section_5']
#         /* Conversion Variables */
#         s.products=metaData['products']
#         s.eVar27=metaData['site_country']
#         s.eVar28=metaData['site_language']
#         s.eVar29=metaData['visitor_segment'] + ': ' + metaData['site_section']
#         s.eVar32=metaData['user_id']
#         s.eVar41=metaData['site_section']
#         s.eVar48=metaData['site_sub_section']
#         s.eVar49=metaData['content_title']
#         s.eVar50=metaData['visitor_segment']
#         s.eVar58=metaData['site_sub_sub_section']
#         s.eVar75=metaData['visitor_sub_segment']
# if(typeof(metaData['score_id']) != "undefined" && typeof(metaData['score_value']) != "undefined") {
#     s.eVar7=metaData['score_id'];
#     s.eVar8="+"+metaData['score_value'];
#     s.events="event18="+metaData['score_value'];
# }        /************* DO NOT ALTER ANYTHING BELOW THIS LINE ! **************/
#         var s_code=s.t();if(s_code)document.write(s_code)//--></script>
# <script language="JavaScript" type="text/javascript"><!--
#         if(navigator.appVersion.indexOf('MSIE')>=0)document.write(unescape('%3C')+'\!-'+'-')
#         //--></script><noscript><img alt="" border="0" height="1" src="http://om.symantec.com/b/ss/veritasnonconsumer/1/H.24.1--NS/0" width="1"/>
# </noscript>
# <!--/DO NOT REMOVE/-->
# <!-- End SiteCatalyst code version: H.24.1. -->
# </body></html>

# %%
# Use a browser to open or download the page
# I used firebug, a FireFox/chrome plug in to analyze the page tag structure
# locate the division where the table is located in
# Find all the tables in this division
division_of_interest = soup.find("div",{'class':'bckSolidWht bckPadLarge clearfix'})
tables = division_of_interest.find_all('table')
print(tables[0])
# Out:
# <table class="defaultTableStyle tableFontMD tableNoBorder">
# <thead>
# <tr>
# <td class="bckSolidDrkGry smallTdPadding">Severity</td><td class="bckSolidDrkGry">Name</td><td class="bckSolidDrkGry">Discovered</td>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=91105" title="Microsoft Internet Explorer XSS Filter CVE-2016-3212 Security Bypass Vulnerability">Microsoft Internet Explorer XSS Filter CVE-2016-3212 Security Bypass Vulnerabili...</a></td><td>06/14/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=95425" title="Microsoft Identity Model Extensions Token Signing Verification Privilege Escalation Vulnerability">Microsoft Identity Model Extensions Token Signing Verification Privilege Escalat...</a></td><td>01/10/2017</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=95318" title="Microsoft Windows LSASS CVE-2017-0004 Denial of Service Vulnerability">Microsoft Windows LSASS CVE-2017-0004 Denial of Service Vulnerability</a></td><td>01/10/2017</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94064" title="Microsoft Windows Kernel 'Win32k.sys' CVE-2016-7255 Local Privilege Escalation Vulnerability">Microsoft Windows Kernel 'Win32k.sys' CVE-2016-7255 Local Privilege Escalation V...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=95287" title="Microsoft Office CVE-2017-0003 Memory Corruption Vulnerability">Microsoft Office CVE-2017-0003 Memory Corruption Vulnerability</a></td><td>01/10/2017</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=95284" title="Microsoft Edge CVE-2017-0002 Remote Privilege Escalation Vulnerability">Microsoft Edge CVE-2017-0002 Remote Privilege Escalation Vulnerability</a></td><td>01/10/2017</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94741" title="Microsoft .NET Framework CVE-2016-7270 Information Disclosure Vulnerability">Microsoft .NET Framework CVE-2016-7270 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="2" src="/images/version-3/level2.png" title="2"/></td><td><a href="/security_response/vulnerability.jsp?bid=94787" title="Microsoft Windows CVE-2016-7295 Local Information Disclosure Vulnerability">Microsoft Windows CVE-2016-7295 Local Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94768" title="Microsoft Windows Installer CVE-2016-7292 DLL Loading Local Privilege Escalation Vulnerability">Microsoft Windows Installer CVE-2016-7292 DLL Loading Local Privilege Escalation...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="2" src="/images/version-3/level2.png" title="2"/></td><td><a href="/security_response/vulnerability.jsp?bid=94764" title="Microsoft Windows Crypto Driver CVE-2016-7219 Local Information Disclosure Vulnerability">Microsoft Windows Crypto Driver CVE-2016-7219 Local Information Disclosure Vulne...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94877" title="Adobe Flash Player APSB16-39 Unspecified Use After Free Remote Code Execution Vulnerability">Adobe Flash Player APSB16-39 Unspecified Use After Free Remote Code Execution Vu...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94668" title="Microsoft Office CVE-2016-7263 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7263 Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94662" title="Microsoft Office CVE-2016-7266 Remote Code Execution Vulnerability">Microsoft Office CVE-2016-7266 Remote Code Execution Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94664" title="Microsoft Office CVE-2016-7267 Security Bypass Vulnerability">Microsoft Office CVE-2016-7267 Security Bypass Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94672" title="Microsoft Office CVE-2016-7268 Information Disclosure Vulnerability">Microsoft Office CVE-2016-7268 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94665" title="Microsoft Office CVE-2016-7275 DLL Loading Remote Code Execution Vulnerability">Microsoft Office CVE-2016-7275 DLL Loading Remote Code Execution Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94666" title="Microsoft Office CVE-2016-7276 Information Disclosure Vulnerability">Microsoft Office CVE-2016-7276 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94670" title="Microsoft Office CVE-2016-7290 Information Disclosure Vulnerability">Microsoft Office CVE-2016-7290 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94771" title="Microsoft Windows Graphics Component CVE-2016-7259 Local Privilege Escalation Vulnerability">Microsoft Windows Graphics Component CVE-2016-7259 Local Privilege Escalation Vu...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94671" title="Microsoft Office CVE-2016-7291 Information Disclosure Vulnerability">Microsoft Office CVE-2016-7291 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94660" title="Microsoft Office CVE-2016-7262 Remote Code Execution Vulnerability">Microsoft Office CVE-2016-7262 Remote Code Execution Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94785" title="Microsoft Windows Kernel 'Win32k.sys' CVE-2016-7260 Local Privilege Escalation Vulnerability">Microsoft Windows Kernel 'Win32k.sys' CVE-2016-7260 Local Privilege Escalation V...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94722" title="Microsoft Internet Explorer and Edge CVE-2016-7287 Remote Memory Corruption Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7287 Remote Memory Corruption Vuln...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94752" title="Microsoft Windows Graphics Component CVE-2016-7273 Remote Code Execution Vulnerability">Microsoft Windows Graphics Component CVE-2016-7273 Remote Code Execution Vulnera...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94739" title="Microsoft Windows Graphics Component CVE-2016-7272 Remote Code Execution Vulnerability">Microsoft Windows Graphics Component CVE-2016-7272 Remote Code Execution Vulnera...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94751" title="Microsoft Edge CVE-2016-7297 Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-7297 Remote Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94750" title="Microsoft Edge CVE-2016-7280 Information Disclosure Vulnerability">Microsoft Edge CVE-2016-7280 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94724" title="Microsoft Internet Explorer and Edge CVE-2016-7282 Information Disclosure Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7282 Information Disclosure Vulner...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94723" title="Microsoft Internet Explorer and Edge CVE-2016-7281 Security Bypass Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7281 Security Bypass Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94784" title="Microsoft Auto Updater for Mac CVE-2016-7300 Local Privilege Escalation Vulnerability">Microsoft Auto Updater for Mac CVE-2016-7300 Local Privilege Escalation Vulnerab...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94715" title="Microsoft Office CVE-2016-7277 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7277 Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94719" title="Microsoft Internet Explorer and Edge CVE-2016-7279 Remote Memory Corruption Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7279 Remote Memory Corruption Vuln...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="2" src="/images/version-3/level2.png" title="2"/></td><td><a href="/security_response/vulnerability.jsp?bid=94736" title="Microsoft Windows Kernel CVE-2016-7258 Local Information Disclosure Vulnerability">Microsoft Windows Kernel CVE-2016-7258 Local Information Disclosure Vulnerabilit...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94734" title="Microsoft Windows CVE-2016-7271 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-7271 Local Privilege Escalation Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94721" title="Microsoft Office CVE-2016-7265 Information Disclosure Vulnerability">Microsoft Office CVE-2016-7265 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94769" title="Microsoft Office CVE-2016-7264 Information Disclosure Vulnerability">Microsoft Office CVE-2016-7264 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94718" title="Microsoft Office CVE-2016-7289 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7289 Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94720" title="Microsoft Office CVE-2016-7298 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7298 Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94758" title="Microsoft Windows Uniscribe CVE-2016-7274 Remote Code Execution Vulnerability">Microsoft Windows Uniscribe CVE-2016-7274 Remote Code Execution Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94748" title="Microsoft Edge CVE-2016-7286 Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-7286 Remote Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94749" title="Microsoft Edge CVE-2016-7288 Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-7288 Remote Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94738" title="Microsoft Edge CVE-2016-7296 Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-7296 Remote Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94737" title="Microsoft Edge CVE-2016-7206 Information Disclosure Vulnerability">Microsoft Edge CVE-2016-7206 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94735" title="Microsoft Edge CVE-2016-7181 Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-7181 Remote Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94755" title="Microsoft Windows Graphics Component CVE-2016-7257 Information Disclosure Vulnerability">Microsoft Windows Graphics Component CVE-2016-7257 Information Disclosure Vulner...</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94725" title="Microsoft Internet Explorer CVE-2016-7284 Information Disclosure Vulnerability">Microsoft Internet Explorer CVE-2016-7284 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94726" title="Microsoft Internet Explorer CVE-2016-7283 Remote Memory Corruption Vulnerability">Microsoft Internet Explorer CVE-2016-7283 Remote Memory Corruption Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94716" title="Microsoft Internet Explorer CVE-2016-7278 Information Disclosure Vulnerability">Microsoft Internet Explorer CVE-2016-7278 Information Disclosure Vulnerability</a></td><td>12/13/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94042" title="Microsoft Edge CVE-2016-7202 Scripting Engine Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-7202 Scripting Engine Remote Memory Corruption Vulnerabi...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94063" title="Microsoft Windows Kernel 'Win32k.sys' CVE-2016-7246 Local Privilege Escalation Vulnerability">Microsoft Windows Kernel 'Win32k.sys' CVE-2016-7246 Local Privilege Escalation V...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94000" title="Microsoft Windows Kernel 'Win32k.sys' CVE-2016-7215 Local Privilege Escalation Vulnerability">Microsoft Windows Kernel 'Win32k.sys' CVE-2016-7215 Local Privilege Escalation V...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94156" title="Microsoft Windows Open Type Font CVE-2016-7256 Remote Code Execution Vulnerability">Microsoft Windows Open Type Font CVE-2016-7256 Remote Code Execution Vulnerabili...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94066" title="Microsoft Windows Media Foundation CVE-2016-7217 Memory Corruption Vulnerability">Microsoft Windows Media Foundation CVE-2016-7217 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94033" title="Microsoft Windows Animation Manager CVE-2016-7205 Memory Corruption Vulnerability">Microsoft Windows Animation Manager CVE-2016-7205 Memory Corruption Vulnerabilit...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94030" title="Microsoft Windows Open Type Font CVE-2016-7210 Information Disclosure Vulnerability">Microsoft Windows Open Type Font CVE-2016-7210 Information Disclosure Vulnerabil...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94056" title="Microsoft SQL Server CVE-2016-7253 Privilege Escalation Vulnerability">Microsoft SQL Server CVE-2016-7253 Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94050" title="Microsoft SQL Server CVE-2016-7252 Information Disclosure Vulnerability">Microsoft SQL Server CVE-2016-7252 Information Disclosure Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94043" title="Microsoft SQL Server Master Data Services CVE-2016-7251 Cross Site Scripting Vulnerability">Microsoft SQL Server Master Data Services CVE-2016-7251 Cross Site Scripting Vul...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94061" title="Microsoft SQL Server CVE-2016-7254 Privilege Escalation Vulnerability">Microsoft SQL Server CVE-2016-7254 Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94060" title="Microsoft SQL Server CVE-2016-7250 Privilege Escalation Vulnerability">Microsoft SQL Server CVE-2016-7250 Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94037" title="Microsoft SQL Server CVE-2016-7249 Privilege Escalation Vulnerability">Microsoft SQL Server CVE-2016-7249 Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94029" title="Microsoft Office CVE-2016-7244 Denial of Service Vulnerability">Microsoft Office CVE-2016-7244 Denial of Service Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94020" title="Microsoft Office CVE-2016-7234 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7234 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94022" title="Microsoft Office CVE-2016-7235 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7235 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94031" title="Microsoft Office CVE-2016-7233 Information Disclosure Vulnerability">Microsoft Office CVE-2016-7233 Information Disclosure Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94025" title="Microsoft Office CVE-2016-7236 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7236 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=93993" title="Microsoft Office CVE-2016-7213 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7213 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=93994" title="Microsoft Office CVE-2016-7228 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7228 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94026" title="Microsoft Office CVE-2016-7245 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7245 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=93996" title="Microsoft Office CVE-2016-7231 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7231 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94005" title="Microsoft Office CVE-2016-7232 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7232 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=93995" title="Microsoft Office CVE-2016-7229 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7229 Memory Corruption Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94018" title="Microsoft Windows CVE-2016-7226 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-7226 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94015" title="Microsoft Windows CVE-2016-7184 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-7184 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94055" title="Microsoft Internet Explorer and Edge CVE-2016-7241 Remote Memory Corruption Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7241 Remote Memory Corruption Vuln...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94053" title="Microsoft Internet Explorer and Edge CVE-2016-7198 Remote Memory Corruption Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7198 Remote Memory Corruption Vuln...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94065" title="Microsoft Internet Explorer and Edge CVE-2016-7227 Information Disclosure Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7227 Information Disclosure Vulner...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94007" title="Microsoft Windows CVE-2016-3343 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-3343 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94057" title="Microsoft Internet Explorer and Edge CVE-2016-7199 Information Disclosure Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7199 Information Disclosure Vulner...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94052" title="Microsoft Internet Explorer and Edge CVE-2016-7195 Remote Memory Corruption Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7195 Remote Memory Corruption Vuln...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94051" title="Microsoft Internet Explorer and Edge CVE-2016-7196 Remote Memory Corruption Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-7196 Remote Memory Corruption Vuln...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94059" title="Microsoft Edge and Internet Explorer XSS Filter CVE-2016-7239 Information Disclosure Vulnerability">Microsoft Edge and Internet Explorer XSS Filter CVE-2016-7239 Information Disclo...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94013" title="Microsoft Windows CVE-2016-3342 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-3342 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94010" title="Microsoft Windows CVE-2016-3340 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-3340 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94040" title="Microsoft Windows CVE-2016-7237 Denial of Service Vulnerability">Microsoft Windows CVE-2016-7237 Denial of Service Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="2" src="/images/version-3/level2.png" title="2"/></td><td><a href="/security_response/vulnerability.jsp?bid=94036" title="Microsoft Windows Virtual Secure Mode CVE-2016-7220 Local Information Disclosure Vulnerability">Microsoft Windows Virtual Secure Mode CVE-2016-7220 Local Information Disclosure...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94045" title="Microsoft Windows NTLM CVE-2016-7238 Local Privilege Escalation Vulnerability">Microsoft Windows NTLM CVE-2016-7238 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94016" title="Microsoft Windows CVE-2016-7225 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-7225 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94014" title="Microsoft Windows CVE-2016-3338 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-3338 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94058" title="Microsoft Windows Boot Manager CVE-2016-7247 Local Security Bypass Vulnerability">Microsoft Windows Boot Manager CVE-2016-7247 Local Security Bypass Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94011" title="Microsoft Windows CVE-2016-3335 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-3335 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94048" title="Microsoft Windows Kernel CVE-2016-7216 Local Privilege Escalation Vulnerability">Microsoft Windows Kernel CVE-2016-7216 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94003" title="Microsoft Windows CVE-2016-7223 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-7223 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94017" title="Microsoft Windows CVE-2016-7224 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-7224 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94028" title="Microsoft Windows Video Control CVE-2016-7248 Remote Code Execution Vulnerability">Microsoft Windows Video Control CVE-2016-7248 Remote Code Execution Vulnerabilit...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94012" title="Microsoft Windows CVE-2016-3334 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-3334 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94009" title="Microsoft Windows CVE-2016-3333 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-3333 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94021" title="Microsoft Windows Input Method Editor CVE-2016-7221 Local Privilege Escalation Vulnerability">Microsoft Windows Input Method Editor CVE-2016-7221 Local Privilege Escalation V...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94008" title="Microsoft Windows CVE-2016-3332 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-3332 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=93998" title="Microsoft Windows CVE-2016-0026 Local Privilege Escalation Vulnerability">Microsoft Windows CVE-2016-0026 Local Privilege Escalation Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94027" title="Microsoft Windows File Manager CVE-2016-7212 Remote Code Execution Vulnerability">Microsoft Windows File Manager CVE-2016-7212 Remote Code Execution Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94023" title="Microsoft Windows Task Scheduler CVE-2016-7222 Local Privilege Escalation Vulnerability">Microsoft Windows Task Scheduler CVE-2016-7222 Local Privilege Escalation Vulner...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=93970" title="Microsoft Edge CVE-2016-7204 Information Disclosure Vulnerability">Microsoft Edge CVE-2016-7204 Information Disclosure Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=93968" title="Microsoft Edge CVE-2016-7200 Scripting Engine Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-7200 Scripting Engine Remote Memory Corruption Vulnerabi...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94047" title="Microsoft Edge CVE-2016-7243 Scripting Engine Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-7243 Scripting Engine Remote Memory Corruption Vulnerabi...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94046" title="Microsoft Edge CVE-2016-7240 Scripting Engine Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-7240 Scripting Engine Remote Memory Corruption Vulnerabi...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=94049" title="Microsoft Edge CVE-2016-7209 Spoofing Vulnerability">Microsoft Edge CVE-2016-7209 Spoofing Vulnerability</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94039" title="Microsoft Edge CVE-2016-7203 Scripting Engine Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-7203 Scripting Engine Remote Memory Corruption Vulnerabi...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=94044" title="Microsoft Edge CVE-2016-7208 Scripting Engine Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-7208 Scripting Engine Remote Memory Corruption Vulnerabi...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94041" title="Microsoft Edge CVE-2016-7242 Scripting Engine Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-7242 Scripting Engine Remote Memory Corruption Vulnerabi...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=94038" title="Microsoft Edge CVE-2016-7201 Scripting Engine Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-7201 Scripting Engine Remote Memory Corruption Vulnerabi...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="2" src="/images/version-3/level2.png" title="2"/></td><td><a href="/security_response/vulnerability.jsp?bid=94004" title="Microsoft Windows Kernel 'Bowser.sys' CVE-2016-7218 Information Disclosure Vulnerability">Microsoft Windows Kernel 'Bowser.sys' CVE-2016-7218 Information Disclosure Vulne...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="2" src="/images/version-3/level2.png" title="2"/></td><td><a href="/security_response/vulnerability.jsp?bid=93991" title="Microsoft Windows Kernel CVE-2016-7214 Local Information Disclosure Vulnerability">Microsoft Windows Kernel CVE-2016-7214 Local Information Disclosure Vulnerabilit...</a></td><td>11/08/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=93861" title="Adobe Flash Player CVE-2016-7855 Use After Free Remote Code Execution Vulnerability">Adobe Flash Player CVE-2016-7855 Use After Free Remote Code Execution Vulnerabil...</a></td><td>10/25/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=48996" title="Microsoft Windows NDISTAPI CVE-2011-1974 Local Privilege Escalation Vulnerability">Microsoft Windows NDISTAPI CVE-2011-1974 Local Privilege Escalation Vulnerabilit...</a></td><td>08/09/2011</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=93386" title="Microsoft Internet Explorer and Edge CVE-2016-3382 Remote Memory Corruption Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-3382 Remote Memory Corruption Vuln...</a></td><td>10/11/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=93396" title="Microsoft Internet Explorer CVE-2016-3383 Remote Memory Corruption Vulnerability">Microsoft Internet Explorer CVE-2016-3383 Remote Memory Corruption Vulnerability</a></td><td>10/11/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=93393" title="Microsoft Internet Explorer CVE-2016-3384 Remote Memory Corruption Vulnerability">Microsoft Internet Explorer CVE-2016-3384 Remote Memory Corruption Vulnerability</a></td><td>10/11/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=93426" title="Microsoft Edge CVE-2016-3386 Scripting Engine Remote Memory Corruption Vulnerability">Microsoft Edge CVE-2016-3386 Scripting Engine Remote Memory Corruption Vulnerabi...</a></td><td>10/11/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=93213" title="Microsoft Azure Active Directory Passport CVE-2016-7191 Authentication Bypass Vulnerability">Microsoft Azure Active Directory Passport CVE-2016-7191 Authentication Bypass Vu...</a></td><td>09/28/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=93556" title="Microsoft Windows Kernel 'Win32k.sys' CVE-2016-7211 Local Privilege Escalation Vulnerability">Microsoft Windows Kernel 'Win32k.sys' CVE-2016-7211 Local Privilege Escalation V...</a></td><td>10/11/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=93372" title="Microsoft Office CVE-2016-7193 Memory Corruption Vulnerability">Microsoft Office CVE-2016-7193 Memory Corruption Vulnerability</a></td><td>10/11/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=93377" title="Microsoft Windows Graphics Component CVE-2016-3393 Remote Code Execution Vulnerability">Microsoft Windows Graphics Component CVE-2016-3393 Remote Code Execution Vulnera...</a></td><td>10/11/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=93392" title="Microsoft Internet Explorer CVE-2016-3298 Multiple Information Disclosure Vulnerabilities">Microsoft Internet Explorer CVE-2016-3298 Multiple Information Disclosure Vulner...</a></td><td>10/11/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=93387" title="Microsoft Internet Explorer and Edge CVE-2016-3331 Remote Memory Corruption Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-3331 Remote Memory Corruption Vuln...</a></td><td>10/11/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=93383" title="Microsoft Internet Explorer and Edge CVE-2016-3390 Remote Memory Corruption Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-3390 Remote Memory Corruption Vuln...</a></td><td>10/11/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=93382" title="Microsoft Internet Explorer and Edge CVE-2016-3388 Remote Privilege Escalation Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-3388 Remote Privilege Escalation V...</a></td><td>10/11/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=93381" title="Microsoft Internet Explorer and Edge CVE-2016-3387 Remote Privilege Escalation Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-3387 Remote Privilege Escalation V...</a></td><td>10/11/2016</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=93379" title="Microsoft Internet Explorer and Edge CVE-2016-3391 Information Disclosure Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-3391 Information Disclosure Vulner...</a></td><td>10/11/2016</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=93376" title="Microsoft Internet Explorer and Edge CVE-2016-3267 Information Disclosure Vulnerability">Microsoft Internet Explorer and Edge CVE-2016-3267 Information Disclosure Vulner...</a></td><td>10/11/2016</td>
# </tr>
# <tr class="odd">
# ...
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=7178" title="Snort TCP Packet Reassembly Integer Overflow Vulnerability">Snort TCP Packet Reassembly Integer Overflow Vulnerability</a></td><td>04/15/2003</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=7919" title="PMachine Lib.Inc.PHP Remote Include Command Execution Vulnerability">PMachine Lib.Inc.PHP Remote Include Command Execution Vulnerability</a></td><td>06/15/2003</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=7539" title="Internet Explorer file:// Request Zone Bypass Vulnerability">Internet Explorer file:// Request Zone Bypass Vulnerability</a></td><td>05/09/2003</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=7781" title="Sun Management Center Change Manager PamVerifier Buffer Overflow Vulnerability">Sun Management Center Change Manager PamVerifier Buffer Overflow Vulnerability</a></td><td>06/02/2003</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=7680" title="FastTrack P2P Supernode Packet Handler Buffer Overflow Vulnerability">FastTrack P2P Supernode Packet Handler Buffer Overflow Vulnerability</a></td><td>05/26/2003</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=7448" title="Apache Mod_Auth_Any Remote Command Execution Vulnerability">Apache Mod_Auth_Any Remote Command Execution Vulnerability</a></td><td>04/28/2003</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=7604" title="IBM AIX Multiple Unspecified Security Vulnerabilities">IBM AIX Multiple Unspecified Security Vulnerabilities</a></td><td>05/13/2003</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=7325" title="Oracle E-Business Suite RRA/FNDFS Arbitrary File Disclosure Vulnerability">Oracle E-Business Suite RRA/FNDFS Arbitrary File Disclosure Vulnerability</a></td><td>04/11/2003</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=6221" title="Microsoft Java Virtual Machine Bytecode Verifier Vulnerability">Microsoft Java Virtual Machine Bytecode Verifier Vulnerability</a></td><td>11/21/2002</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=6666" title="Microsoft Windows Locator Service Buffer Overflow Vulnerability">Microsoft Windows Locator Service Buffer Overflow Vulnerability</a></td><td>01/22/2003</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=6870" title="IBM Lotus Domino HTTP Redirect Buffer Overflow Vulnerability">IBM Lotus Domino HTTP Redirect Buffer Overflow Vulnerability</a></td><td>02/17/2003</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=6895" title="Cisco IOS OSPF Neighbor Buffer Overflow Vulnerability">Cisco IOS OSPF Neighbor Buffer Overflow Vulnerability</a></td><td>02/20/2003</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=6754" title="Opera Cross Domain Scripting Vulnerability">Opera Cross Domain Scripting Vulnerability</a></td><td>02/04/2003</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=5980" title="Microsoft SQL Server Web Task Stored Procedure Privilege Escalation Vulnerability">Microsoft SQL Server Web Task Stored Procedure Privilege Escalation Vulnerabilit...</a></td><td>10/16/2002</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=6627" title="ISC DHCPD NSUPDATE MiniRes Library Remote Buffer Overflow Vulnerabilities">ISC DHCPD NSUPDATE MiniRes Library Remote Buffer Overflow Vulnerabilities</a></td><td>01/15/2003</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=6024" title="Multiple Vendor kadmind Remote Buffer Overflow Vulnerability">Multiple Vendor kadmind Remote Buffer Overflow Vulnerability</a></td><td>10/21/2002</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=6582" title="Half-Life Client Server Message Format String Vulnerability">Half-Life Client Server Message Format String Vulnerability</a></td><td>01/10/2003</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=6533" title="Longshine Wireless Access Point Devices Information Disclosure Vulnerability">Longshine Wireless Access Point Devices Information Disclosure Vulnerability</a></td><td>01/06/2003</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=6497" title="Perl-HTTPd File Disclosure Vulnerability">Perl-HTTPd File Disclosure Vulnerability</a></td><td>12/31/2002</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=6366" title="Microsoft Internet Explorer PNG Deflate Heap Corruption Vulnerability">Microsoft Internet Explorer PNG Deflate Heap Corruption Vulnerability</a></td><td>12/12/2002</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=6326" title="Cobalt RaQ4 Administrative Interface Command Execution Vulnerability">Cobalt RaQ4 Administrative Interface Command Execution Vulnerability</a></td><td>12/05/2002</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=6264" title="Lib CGI Include Buffer Overflow Vulnerability">Lib CGI Include Buffer Overflow Vulnerability</a></td><td>11/27/2002</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=6122" title="Macromedia JRun IIS ISAPI Filter GET Request Buffer Overrun Vulnerability">Macromedia JRun IIS ISAPI Filter GET Request Buffer Overrun Vulnerability</a></td><td>11/07/2002</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=6171" title="TCPDump / LIBPCap Trojan Horse Vulnerability">TCPDump / LIBPCap Trojan Horse Vulnerability</a></td><td>11/13/2002</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=5955" title="Linux-HA Heartbeat Remote Buffer Overflow Vulnerability">Linux-HA Heartbeat Remote Buffer Overflow Vulnerability</a></td><td>10/14/2002</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=6068" title="Multiple Microsoft IIS Vulnerabilities">Multiple Microsoft IIS Vulnerabilities</a></td><td>10/30/2002</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=5921" title="Sendmail Trojan Horse Vulnerability">Sendmail Trojan Horse Vulnerability</a></td><td>10/08/2002</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=5811" title="Multiple OpenVMS WASD HTTP Server Vulnerabilities">Multiple OpenVMS WASD HTTP Server Vulnerabilities</a></td><td>09/26/2002</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=5748" title="Microsoft Virtual Machine Multiple JDBC Vulnerabilities">Microsoft Virtual Machine Multiple JDBC Vulnerabilities</a></td><td>09/19/2002</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="5" src="/images/version-3/level5.png" title="5"/></td><td><a href="/security_response/vulnerability.jsp?bid=5609" title="Multiple Cisco VPN 3000 Vulnerabilities">Multiple Cisco VPN 3000 Vulnerabilities</a></td><td>09/03/2002</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=2032" title="AIX setsenv Buffer Overflow Vulnerability">AIX setsenv Buffer Overflow Vulnerability</a></td><td>12/01/2000</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=2033" title="AIX digest Buffer Overflow Vulnerability">AIX digest Buffer Overflow Vulnerability</a></td><td>12/01/2000</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=2863" title="Microsoft SQL Server Administrator Cached Connection Vulnerability">Microsoft SQL Server Administrator Cached Connection Vulnerability</a></td><td>06/12/2001</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=2368" title="Microsoft Windows NT PPTP DoS Vulnerability">Microsoft Windows NT PPTP DoS Vulnerability</a></td><td>02/13/2001</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=2282" title="Netscape Enterprise Server DoS Vulnerability">Netscape Enterprise Server DoS Vulnerability</a></td><td>01/22/2001</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=2270" title="GoodTech FTP Server Denial of Service">GoodTech FTP Server Denial of Service</a></td><td>01/22/2001</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="2" src="/images/version-3/level2.png" title="2"/></td><td><a href="/security_response/vulnerability.jsp?bid=2005" title="Winsock FTPd Directory Transversal Vulnerability">Winsock FTPd Directory Transversal Vulnerability</a></td><td>11/27/2000</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=1994" title="Lotus Notes Client R5 File Existence Verification Vulnerability">Lotus Notes Client R5 File Existence Verification Vulnerability</a></td><td>11/24/2000</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=2049" title="Quikstore File Disclosure Vulnerability">Quikstore File Disclosure Vulnerability</a></td><td>11/20/2000</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="2" src="/images/version-3/level2.png" title="2"/></td><td><a href="/security_response/vulnerability.jsp?bid=1959" title="Joe Text Editor DEADJOE Symbolic Link Vulnerability">Joe Text Editor DEADJOE Symbolic Link Vulnerability</a></td><td>11/16/2000</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="2" src="/images/version-3/level2.png" title="2"/></td><td><a href="/security_response/vulnerability.jsp?bid=1943" title="Kenny Carruthers Postmaster 1.0 Buffer Overflow Vulnerability">Kenny Carruthers Postmaster 1.0 Buffer Overflow Vulnerability</a></td><td>11/14/2000</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="2" src="/images/version-3/level2.png" title="2"/></td><td><a href="/security_response/vulnerability.jsp?bid=1920" title="McAfee VirusScan 4.5 Unquoted ImagePath Vulnerability">McAfee VirusScan 4.5 Unquoted ImagePath Vulnerability</a></td><td>11/03/2000</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=1780" title="Microsoft Windows 9x / Me Share Level Password Bypass Vulnerability">Microsoft Windows 9x / Me Share Level Password Bypass Vulnerability</a></td><td>10/10/2000</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=1781" title="Microsoft Windows 9x / Me IPX NMPI Packet DoS Vulnerability">Microsoft Windows 9x / Me IPX NMPI Packet DoS Vulnerability</a></td><td>10/10/2000</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=1671" title="Microsoft WebTV DoS Vulnerability">Microsoft WebTV DoS Vulnerability</a></td><td>09/12/2000</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=1466" title="Microsoft SQL Server Enterprise Manager Password Disclosure Vulnerability">Microsoft SQL Server Enterprise Manager Password Disclosure Vulnerability</a></td><td>07/11/2000</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=1451" title="Microsoft Excel 97 / 2000 Register.ID Vulnerability">Microsoft Excel 97 / 2000 Register.ID Vulnerability</a></td><td>07/11/2000</td>
# </tr>
# <tr class="even">
# <td class="smallTdPadding"><img alt="3" src="/images/version-3/level3.png" title="3"/></td><td><a href="/security_response/vulnerability.jsp?bid=2126" title="iCat Carbo Server File Disclosure Vulnerability">iCat Carbo Server File Disclosure Vulnerability</a></td><td>11/08/1997</td>
# </tr>
# <tr class="odd">
# <td class="smallTdPadding"><img alt="4" src="/images/version-3/level4.png" title="4"/></td><td><a href="/security_response/vulnerability.jsp?bid=2078" title="OReilly WebSite 1.x/2.0 win-c-sample.exe Buffer Overflow Vulnerability">OReilly WebSite 1.x/2.0 win-c-sample.exe Buffer Overflow Vulnerability</a></td><td>01/06/1997</td>
# </tr>
# </tbody>
# </table>

# %%
#retrieve all the rows from the first table 
rows = tables[0].findAll('tr')

# %%
#create lists to store retrieved data

#vulnerablility names
vul_names =[]

#discovered dates
date_values=[]

#severity level from 1 to 5
severity_values = []

#the urls of the vulnerbility description pages
url_values = []

#in each row
for tr in rows: 
    # if it's not the first row
    # use tr(text=True) to determine if it's the first row
    if "Discovered" not in tr(text=True):
        #severity level is the value of the title attribute in the img tag
        severity = tr.find('img')['title']
        #append to the list
        severity_values.append(severity)
        
        #find all the a tags in the row
        a_tag = tr.find('a')
        #vulnerbility name is the first text of the <a> tag
        vul = a_tag(text=True)[0]
        vul_names.append(vul)
        
        #construct the URLs 
        url_values.append("https://www.symantec.com/"+a_tag['href'])
        
        #date is the text of the last <td> tag
        td = tr.findAll('td')
        #remove the <td></td> tags from the string
        date = str(td[-1]).replace("<td>",'').replace("</td>","")
        #add date to the date_values list
        date_values.append(date)

# %%
#test to see the values
print(date_values[30])
print(url_values[30])
# Out:
# 12/13/2016
# https://www.symantec.com//security_response/vulnerability.jsp?bid=94715

# %%
#use input() to get user input
#cast the input to integer
user_severity = int(input("please choose a severity level equal to or above : "))

#find all vulnerbilities associated with "Adobe" and with a severity higher than user_severity
for index in range(len(vul_names)):
    if int(severity_values[index]) >= user_severity:
        if (vul_names[index].count('Adobe') > 0):
            print(vul_names[index])
# Out:
# please choose a severity level equal to or above : 4
# Adobe Flash Player APSB16-39 Unspecified Use After Free Remote Code Execution Vu...
# Adobe Flash Player CVE-2016-7855 Use After Free Remote Code Execution Vulnerabil...
# Adobe Flash Player APSB16-29 Multiple Unspecified Memory Corruption Vulnerabilit...
# Adobe Flash Player APSB16-25 Multiple Use After Free Remote Code Execution Vulne...
# Adobe Acrobat and Reader APSB16-26 Multiple Unspecified Memory Corruption Vulner...
# Adobe Flash Player APSB16-25 Multiple Unspecified Memory Corruption Vulnerabilit...
# Adobe Flash Player Multiple Unspecified Security Vulnerabilities
# Adobe Flash Player CVE-2015-3113 Unspecified Heap Buffer Overflow Vulnerability
# Adobe Flash Player and AIR CVE-2015-8651 Unspecified Integer Overflow Vulnerabil...
# Adobe Flash Player and AIR APSB15-32 Multiple Unspecified Memory Corruption Vuln...
# Adobe Flash Player ActionScript 3 ByteArray Use After Free Remote Memory Corrupt...
# Adobe Flash Player CVE-2015-7645 Remote Code Execution Vulnerability
# Adobe Flash Player and AIR APSB15-28 Multiple Use After Free Remote Code Executi...
# Adobe Flash Player and AIR APSB15-25 Multiple Unspecified Memory Corruption Vuln...
# Adobe Flash Player and AIR CVE-2015-7632 Buffer Overflow Vulnerability
# Adobe Flash Player and AIR APSB15-25 Multiple Use After Free Remote Code Executi...
# Adobe Flash Player and AIR APSB15-19 Multiple Use After Free Remote Code Executi...
# Adobe Flash Player Multiple Unspecified Memory Corruption Vulnerabilities
# Adobe Reader and Acrobat JavaScript API Execution Multiple Security Bypass Vulne...
# Microsoft Windows Adobe Font Driver CVE-2015-0093 Remote Code Execution Vulnerab...
# Microsoft Windows Adobe Font Driver CVE-2015-0092 Remote Code Execution Vulnerab...
# Microsoft Windows Adobe Font Driver CVE-2015-0091 Remote Code Execution Vulnerab...
# Microsoft Windows Adobe Font Driver CVE-2015-0090 Remote Code Execution Vulnerab...
# Microsoft Windows Adobe Font Driver CVE-2015-0088 Remote Code Execution Vulnerab...
# Adobe Flash Player and AIR CVE-2014-0569 Integer Overflow Vulnerability
# Adobe Flash Player CVE-2015-0313 Remote Code Execution Vulnerability
# Adobe Flash Player CVE-2015-0336 Type Confusion Remote Code Execution Vulnerabil...
# Adobe Flash Player and AIR CVE-2014-8440 Unspecified Memory Corruption Vulnerabi...
# Adobe Flash Player Multimedia File Remote Buffer Overflow Vulnerability
# Adobe Reader 'util.printf()' JavaScript Function Stack Buffer Overflow Vulnerabi...
# Adobe Flash Player CVE-2015-0339 Unspecified Memory Corruption Vulnerability
# Adobe Flash Player CVE-2015-0338 Remote Integer Overflow Vulnerability
# Adobe Flash Player CVE-2015-0312 Double Free Remote Code Execution Vulnerability
# Adobe Flash Player CVE-2015-0310 Unspecified Memory Corruption Vulnerability
# Adobe Flash Player CVE-2014-9163 Stack Based Buffer Overflow Vulnerability
# Adobe Flash Player and AIR CVE-2014-0588 Use After Free Remote Code Execution Vu...
# Adobe Flash Player and AIR CVE-2014-0577 Type Confusion Remote Code Execution Vu...
# Adobe Reader and Acrobat CVE-2014-0565 Remote Code Execution Vulnerability
# Adobe Flash Player CVE-2014-0515 Buffer Overflow Vulnerability
# Adobe Acrobat and Reader CVE-2014-0546 Unspecified Security Bypass Vulnerability
# Adobe Flash Player CVE-2014-0497 Remote Code Execution Vulnerability
# Adobe Flash Player CVE-2013-0634 Remote Memory Corruption Vulnerability
# Adobe Acrobat and Reader CVE-2014-0496 Remote Code Execution Vulnerability
# Adobe Acrobat And Reader CVE-2013-0640 Remote Code Execution Vulnerability
# Adobe Flash Player CVE-2013-0633 Buffer Overflow Vulnerability
# Adobe Acrobat And Reader  CVE-2013-0641 Remote Code Execution Vulnerability
# Adobe Acrobat and Reader CVE-2013-0604 Remote Heap Based Buffer Overflow Vulnera...
# Adobe Acrobat and Reader CVE-2012-2049 Remote Buffer Overflow Vulnerability
# Adobe Acrobat and Reader CVE-2010-0188 Remote Code Execution Vulnerability
# Adobe Flash Player CVE-2012-1535 Remote Code Execution Vulnerability
# Adobe Flash Player CVE-2012-0779 Object Type Confusion Remote Code Execution Vul...
# Adobe Flash Player CVE-2012-0754 Remote Memory Corruption Vulnerability
# Adobe Flash Player CVE-2011-0611 'SWF' File Remote Memory Corruption Vulnerabili...
# Adobe Flash Player CVE-2011-2452 Remote Memory Corruption Vulnerability
# Adobe Acrobat and Reader U3D Memory Corruption Vulnerability
# Adobe Reader 9.4 Remote Memory Corruption Vulnerability
# Adobe Acrobat and Reader CVE-2011-2097 Remote Buffer Overflow Vulnerability
# Adobe Flash Player ActionScript Virtual Machine CVE-2011-0618 Remote Integer Ove...
# Adobe Flash Player CVE-2011-0619 Remote Memory Corruption Vulnerability
# Adobe Flash Player CVE-2011-0609 'SWF' File Remote Memory Corruption Vulnerabili...
# Adobe Acrobat and Reader CVE-2011-2096 Remote Heap Buffer Overflow Vulnerability
# Adobe Flash Player CVE-2010-3648 Remote Memory Corruption Vulnerability
# Adobe Flash Player CVE-2010-3643 Remote Memory Corruption Vulnerability
# Adobe Acrobat, Reader, and Flash CVE-2010-3654 Remote Code Execution Vulnerabili...
# Adobe Flash Player CVE-2010-2884 Unspecified Remote Code Execution Vulnerability
# Adobe Flash Player, Reader, and Acrobat 'authplay.dll' Remote Code Execution Vul...
# Adobe Reader 'CoolType.dll' TTF Font Remote Code Execution Vulnerability
# Adobe Acrobat and Reader 'AcroForm.api' GIF Image Remote Code Execution Vulnerab...
# Adobe Acrobat and Reader CVE-2010-1241 'CoolType.dll' Remote Code Execution Vuln...
# Adobe Acrobat and Reader CVE-2010-0195 Embedded Font Handling Remote Code Execut...
# Adobe Reader and Acrobat 'newplayer()' JavaScript Method Remote Code Execution V...
# Adobe Acrobat and Reader CLOD Mesh Declaration Block Heap Buffer Overflow Vulner...
# Adobe Acrobat and Reader Font Parsing Remote Code Execution Vulnerability
# Adobe Reader and Acrobat U3D File Invalid Array Index Remote Vulnerability
# Adobe Illustrator Encapsulated Postscript File Remote Buffer Overflow Vulnerabil...
# Adobe Acrobat Reader Remote Code Execution Vulnerability
# Adobe Acrobat, Reader, and Flash Player Remote Code Execution Vulnerability
# Adobe Acrobat and Reader Collab 'getIcon()' JavaScript Method Remote Code Execut...
# Adobe Acrobat and Reader PDF File Handling JBIG2 Image Remote Code Execution Vul...
# Adobe Reader 'spell.customDictionaryOpen()' JavaScript Function Remote Code Exec...
# Adobe Reader 'getAnnots()' JavaScript Function Remote Code Execution Vulnerabili...
# Multiple Adobe Products BMP Image Header Buffer Overflow Vulnerability
# Adobe Acrobat and Reader Multiple Arbitrary Code Execution and Security Vulnerab...
# Adobe Acrobat Mailto PDF File Command Execution Vulnerability

# %%
#the date_values are in string format
#we need convert them to datetime format so we can compare them with 
#the time boundaries users set
date_values[40]
# Out:
# '12/13/2016'

# %%
#after search on the internet, we found the datetime package for this purpose
from datetime import datetime

# %%
#define a time based on a specific format
a = datetime.strptime('1/30/2011',"%m/%d/%Y")

# %%
#compare the time with 2015/12/2
#the result is correct
print(a > datetime(2015,12,2))
# Out:
# False

# %%
#open the vul description page one at a time
for index in range(100):
    response = requests.get(url_values[index])
    content =response.content
    soup = BeautifulSoup(content,"lxml")
